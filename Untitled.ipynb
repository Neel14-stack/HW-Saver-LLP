# %%
import pandas as pd
df = pd.read_csv("Raw_Skills_Dataset.csv")
df.shape
# Out:
# (34116, 1)

# %%
df.head()
# Out:
#           RAW DATA
# 0         What ifs
# 1        seniority
# 2      familiarity
# 3  functionalities
# 4          Lambdas

# %%
df.dropna(inplace = True)
df.drop_duplicates(inplace = True)

# %%
df.shape
# Out:
# (15677, 1)

# %%
y = df['RAW DATA'].str.findall(r'(^[A-Z].*)')

# %%
y.replace(to_replace ="\d+",
                 value ="")
# Out:
# 0                                             [What ifs]
# 1                                                     []
# 2                                                     []
# 3                                                     []
# 4                                              [Lambdas]
#                               ...
# 34106                             [Leadership qualities]
# 34108                                         [Actalent]
# 34109                                                 []
# 34110    [Self-motivated, enthusiastic and strong drive]
# 34111                                                 []
# Name: RAW DATA, Length: 15677, dtype: object

# %%
y.to_csv("df1.csv", index = False)

# %%
df1 = pd.read_csv("df1.csv")
df1.head(20)
# Out:
#                         RAW DATA
# 0                   ['What ifs']
# 1                             []
# 2                             []
# 3                             []
# 4                    ['Lambdas']
# 5               ['Java Streams']
# 6   ['Object Oriented analysis']
# 7       ['Relational Databases']
# 8                        ['SQL']
# 9                        ['ORM']
# 10                      ['JPA2']
# 11                 ['Hibernate']
# 12                   ['MyBatis']
# 13                            []
# 14         ['Git.. Familiarity']
# 15                     ['Maven']
# 16      ['Gradle.. Familiarity']
# 17                            []
# 18                            []
# 19                            []

# %%
l = []
from csv import DictReader
with open("try.csv",'r',encoding="utf-8") as f:
    csv_dict_reader = DictReader(f)
    for row in csv_dict_reader:
        l.append(row['RAW DATA'])
        #print(row['RAW DATA'])

# %%
a = []
for i in l:
    if i!='[]':
        a.append(i)

# %%
pd.set_option('display.max_rows', None)
a
# Out:
# ["['What ifs']",
#  "['Lambdas']",
#  "['Java Streams']",
#  "['Object Oriented analysis']",
#  "['Relational Databases']",
#  "['SQL']",
#  "['ORM']",
#  "['JPA']",
#  "['Hibernate']",
#  "['MyBatis']",
#  "['Git.. Familiarity']",
#  "['Maven']",
#  "['Gradle.. Familiarity']",
#  "['Familiarity']",
#  "['Demonstrable experience']",
#  "['Bachelor or Master degree']",
#  "['STEM majors']",
#  "['Strong algorithms']",
#  "['Python']",
#  "['Scala programming experience']",
#  "['Exceptional proficiency']",
#  "['MySQL']",
#  "['Oracle']",
#  "['NoSQL Stores']",
#  "['Clickhouse']",
#  "['Distributed Processing Engines']",
#  "['Apache Flink']",
#  "['Celery']",
#  "['Distributed Queues']",
#  "['AWS Kinesis']",
#  "['GCP PusSub']",
#  "['GCP']",
#  "['Azure']",
#  "['AWS']",
#  "['Excellent Unix/Linux experience and programming experience']",
#  "['IPC mechanisms']",
#  "['TCP/IP']",
#  "['Kafka']",
#  "['API gateways']",
#  "['CAP Theorem']",
#  "['RAFT']",
#  "['Paxos']",
#  "['CI/CD']",
#  "['Github']",
#  "['Makefiles']",
#  "['Microservices']",
#  "['GCPNode.js']",
#  "['REST APIs servicesExperience writing tools']",
#  "['Ruby']",
#  "['PerlExperience']",
#  "['Bazel']",
#  "['HTTP /websocket']",
#  "['Redis']",
#  "['Web UIExperience']",
#  "['JavaScript']",
#  "['HTML']",
#  "['CSS']",
#  "['Angular']",
#  "['Meteor']",
#  "['Ember']",
#  "['Knockout']",
#  "['UI Component libraries']",
#  "['Vue']",
#  "['Bootstrap']",
#  "['ES']",
#  "['TypeScript']",
#  "['Dependency injection patterns']",
#  "['Async Module Definition']",
#  "['AMD, requireJS']",
#  "['Stylesheet languages']",
#  "['SASS']",
#  "['Redux']",
#  "['Reactive Programming']",
#  "['RxJS']",
#  "['JavaStrong programming skills']",
#  "['Guice knowledge']",
#  "['Protobuf knowledge']",
#  "['APIs']",
#  "['Web UI:Deep understanding']",
#  "['JSON']",
#  "['JavaScript Design']",
#  "['Architectural Patterns']",
#  "['Proficiency']",
#  "['Spring/Guice']",
#  "['JPA/Hibernate']",
#  "['JavaExperience']",
#  "['Containers knowledge']",
#  "['Multi-threaded concepts']",
#  "['NoSQL']",
#  "['MongoDB']",
#  "['Cassandra']",
#  "['Java Application Servers']",
#  "['Oracle WebLogic']",
#  "['JBoss']",
#  "['Tomcat']",
#  "['Jasmine']",
#  "['Karma']",
#  "['Protractor']",
#  "['Junit']",
#  "['Cross-browser techniques']",
#  "['Chrome Dev Tools']",
#  "['Responsive design implementation']",
#  "['Browser performance auditing']",
#  "['Scrum / Kanban']",
#  "['Guice']",
#  "['GRPC']",
#  "['Excellent analytical and problem-solving skills']",
#  "['Proven-deep-expertise']",
#  "['Python programming']",
#  "['Django']",
#  "['Flask']",
#  "['Unix / Linux command line']",
#  "['Object-oriented concepts']",
#  "['UI frameworks']",
#  "['Hadoop / Hive / Presto']",
#  "['ML/AI frameworks']",
#  "['TensorFlow']",
#  "['H']",
#  "['Mesos']",
#  "['Kubernetes']",
#  "['Application benchmarking']",
#  "['Building user interface applications']",
#  "['UI Applications']",
#  "['QML']",
#  "['Qt/C++']",
#  "['RasPi']",
#  "['BeagleBone']",
#  "['IP-based network protocols']",
#  "['Myntra’s new product platforms']",
#  "['Architects']",
#  "['DevOps engineers']",
#  "['Myntra']",
#  "['Java/GO']",
#  "['Developing user-facing web applications']",
#  "['Bachelor']",
#  "['Backend services']",
#  "['React JS']",
#  "['JS/TypeScript']",
#  "['Webpack bundling']",
#  "['Dev tools']",
#  "['HTML']",
#  "['CSS']",
#  "['SCSS']",
#  "['Mysql']",
#  "['Postgres']",
#  "['Data modeling skills']",
#  "['Detail Design phases']",
#  "['Minimum  year Java design and development experience']",
#  "['Spring and Hibernate based solutions']",
#  "['High-Quality Deliverables']",
#  "['SOPs']",
#  "['Checks programming logs']",
#  "['Inputs']",
#  "['Handles']",
#  "['Programs TLFs']",
#  "['EAC']",
#  "['BIOSETUP']",
#  "['SAP']",
#  "['Shares accountability']",
#  "['ADaM reviewers guide']",
#  "['SDRG']",
#  "['ADRG']",
#  "['RFPs']",
#  '["Master\'s Degree Computer science"]',
#  '["Bachelor\'s Degree Computer science"]',
#  "['CDISC/ADaM/SDTM']",
#  "['Base SAS']",
#  "['SAS/STAT']",
#  "['SAS Macro Language']",
#  "['Good organizational, interpersonal, leadership and communication skills']",
#  "['Coda']",
#  "['ETL']",
#  "['AWS technologies']",
#  "['Redshift']",
#  "['S']",
#  "['EMR']",
#  "['EC']",
#  "['DynamoDB']",
#  "['Kinesis Firehose']",
#  "['Lambda']",
#  "['ML teams']",
#  "['Tableau']",
#  "['Bachelor’s degree']",
#  "['Hadoop/MapReduce/AWS']",
#  "['Spark/Scala/PySpark/ Apache Kafka / Kinesis Streams / AWS Glue']",
#  "['Experience building flexible data APIs']",
#  "['Agile Development']",
#  "['Collaborative Filtering']",
#  "['Preferably, apps']",
#  "['XCode.. Experience']",
#  "['Multi-threading and performance & memory optimization']",
#  "['RESTful APIs']",
#  "['Proficient understanding']",
#  "['Git']",
#  "['Rubrik Software Engineers']",
#  "['Master’s degree']",
#  "['Scala']",
#  "['Google Cloud Platform/AWS/Azure']",
#  "['Unix/Linux environments']",
#  "['Windows environments']",
#  "['Kubernetes Service']",
#  "['RESTful services']",
#  "['Entity Framework']",
#  "['Nhibernate']",
#  "['Strong TDD approach']",
#  "['Nunit']",
#  "['OOP and SOLID design principles']",
#  "['Highly efficient data persistent design techniques']",
#  "['Proficient experience']",
#  "['Microsoft SQL Server/Postgres']",
#  "['Agile practices']",
#  "['Debugging/Troubleshooting functional and technical issues']",
#  "['Performance/Optimization techniques']",
#  "['Excellent analytical, quantitative, and problem-solving abilities']",
#  "['Strong interpersonal']",
#  "['Xamarin']",
#  "['LINQ']",
#  "['Rest APIs']",
#  "['Xamarin Forms']",
#  "['Xamarin Native development']",
#  "['Xamarin Studio']",
#  "['Xamarin Apps']",
#  "['UWP']",
#  "['XAML']",
#  "['Azure Active Directory']",
#  "['Notifications']",
#  "['HockeyApp/Visual Studio App Center']",
#  "['Continuous Integration']",
#  "['CI']",
#  "['DevOps']",
#  "['Automation Testing']",
#  "['Xamarin Profiler']",
#  "['Various code repositories']",
#  "['TFS']",
#  "['MVVM Architecture']",
#  "['VSTS']",
#  "['Overall Cross Platform app development ecosystem']",
#  "['Portable Class Library']",
#  "['PCL']",
#  "['SQLite']",
#  "['Xamarin Binding']",
#  "['SAP HANA REST API Integration']",
#  "['Core Java']",
#  "['Swift / XCode']",
#  "['CRM']",
#  "['CMS']",
#  "['Highspot’s external API']",
#  "['Highspot’s Salesforce integrations']",
#  "['UX']",
#  "['Highspot’s Infrastructure Platform crew']",
#  "['Highspot']",
#  "['Highspot’s feature engineering crews']",
#  "['Clojure']",
#  "['Node']",
#  "['Typescript']",
#  "['Operational efficiencies']",
#  "['Collaborative build practices']",
#  "['API']",
#  "['UI components']",
#  "['Automated analysis']",
#  "['UI']",
#  "['Data annotation']",
#  "['Degree qualification']",
#  "['Ideally some exposure']",
#  "['Workplace Search']",
#  "['Elasticsearch']",
#  "['Kibana']",
#  "['DevOPS']",
#  "['Self-starter']",
#  "['SLA']",
#  "['Strong TCP/IP knowledge']",
#  "['Proxies']",
#  "['NG Firewalls']",
#  "['SSL/IPSec']",
#  "['VPN']",
#  "['SSO']",
#  "['DLP and Encryption gateways']",
#  "['UNIX/Linux']",
#  "['Windows\\xad based systems']",
#  "['DNS']",
#  "['DHCP']",
#  "['Strong empathy']",
#  "['Interpersonal Skills']",
#  "['Zendesk']",
#  "['Bachelors or Masters degree']",
#  "['Excellent grasp']",
#  "['MLOps processes']",
#  "['SparkML']",
#  "['NumPy']",
#  "['Tensorflow']",
#  "['PyTorch']",
#  "['Keras']",
#  "['Spark']",
#  "['Jenkins']",
#  "['GNN']",
#  "['RL']",
#  "['Recommender Systems']",
#  "['NLP techniques']",
#  "['Analyzes']",
#  "['QA test plans']",
#  "['SDLC']",
#  "['Agile']",
#  "['Micro-services architecture']",
#  "['OpenShift']",
#  "['K cluster']",
#  "['Nginx/Ingres']",
#  "['API Gateway']",
#  "['Service Mesh']",
#  "['TortoiseGit / Sourcetree']",
#  "['BitBucket']",
#  "['JIRA']",
#  "['Mockito']",
#  "['Application Servers']",
#  "['WebSphere']",
#  "['Database Servers']",
#  "['PostgreSQL']",
#  "['MSSQL']",
#  "['Linux']",
#  "['Object Oriented Programming knowledge']",
#  "['JAXB']",
#  "['Apache Commons']",
#  "['Apache POI']",
#  "['Eclipse / STS']",
#  "['XML']",
#  "['XSD']",
#  "['Apache Ant']",
#  "['Linux bash scripting']",
#  "['DDL']",
#  "['DML']",
#  "['JDBC']",
#  "['Java Message Service']",
#  "['JMS']",
#  "['LiveView']",
#  "['Rails']",
#  "['API development']",
#  "['Sinatra']",
#  "['GitHub']",
#  "['A strong grasp']",
#  "['Exq']",
#  "['Sidekiq']",
#  "['Beanstalk']",
#  "['RabbitMQ']",
#  "['ExUnit']",
#  "['RSpec']",
#  "['Jest']",
#  "['Elixir']",
#  "['GraphQL APIs']",
#  "['Absinthe']",
#  "['GraphQL']",
#  "['JavaScript SSR']",
#  "['Willingness']",
#  "['MySql']",
#  "['Deployment']",
#  "['RESTful webservices']",
#  "['InfluxDB']",
#  "['Prometheus']",
#  "['ReactJS']",
#  "['UI changes']",
#  "['UI Team']",
#  "['HTML/CSS/SASS']",
#  "['QA']",
#  "['REST APIs']",
#  "['Mocha']",
#  "['UX teams']",
#  "['CI tools']",
#  "['Dev-Ops Deployment process']",
#  "['BDD/TDD']",
#  "['BDD Experience']",
#  "['RESTFUL API']",
#  "['Scripting']",
#  "['Grafana']",
#  "['NewRelic']",
#  "['Stackdriver']",
#  "['Sumo Logic']",
#  "['CloudWatch']",
#  "['BS/MS']",
#  "['Docker']",
#  "['Perforce']",
#  "['Android java']",
#  "['Android Kotlin']",
#  "['Buck/Bazel']",
#  "['Golang']",
#  "['REST/GraphQL']",
#  "['SQL/NoSQL Databases']",
#  "['Micronaut']",
#  "['Quarkus']",
#  "['NoSQL Databases']",
#  "['Event Brokers']",
#  "['FaaS']",
#  "['Terraform’s open source and commercial offerings']",
#  "['HashiCorp customers']",
#  "['Ph.D.']",
#  "['ML techniques']",
#  "['SVMs']",
#  "['Entrepreneurial and positive attitude']",
#  "['Fortune  companies']",
#  '["Bachelor\'s degree"]',
#  "['Networking']",
#  "['HTTPS/SSL']",
#  "['VLANs, TCP/IP']",
#  "['NAT devices']",
#  "['DHCP servers']",
#  "['Firewalls']",
#  "['Genuine excitement']",
#  "['IoT']",
#  "['Industry certifications']",
#  "['CCNA']",
#  "['CCDA']",
#  "['CCNP']",
#  "['MCSE']",
#  "['CEH']",
#  "['Microsoft Azure']",
#  "['CISSP']",
#  "['CSP']",
#  "['Linux systems']",
#  "['Good theoretical grounding']",
#  "['Excellent stakeholder communication']",
#  "['Natural Language ProcessingContent & Context UnderstandingRecommender SystemsGraph / Geometric Deep LearningModel']",
#  "['NetSuite']",
#  "['Netsuite ERP - Implementation']",
#  "['Avalara']",
#  "['Billing']",
#  "['ERP']",
#  "['NetSuite ERP experience']",
#  "['Salesforce.com']",
#  "['Javascript']",
#  "['Unix scripts tool set']",
#  "['SuiteScript']",
#  "['SuiteFlows']",
#  "['Web Services/SuiteTalk']",
#  "['Exceptional communicator']",
#  "['NetSuite Administrator Certification']",
#  "['Bachelors or masters degree']",
#  "['ERP implementation experience']",
#  "['Excellent JavaScript development skills']",
#  "['Node.js ecosystem']",
#  "['Cloud environments']",
#  "['React web app development']",
#  "['UIs']",
#  "['Experience building API gateways']",
#  "['CI/CD technology']",
#  "['Real-time D/D applications']",
#  "['Mentor']",
#  "['TPM']",
#  "['VM/container management']",
#  "['Proven programming skills']",
#  "['Node.js']",
#  "['Demonstrable understanding']",
#  "['Observance']",
#  "['Clean architectural and coding principles']",
#  "['Good problem-solving skills']",
#  "['Excellent verbal communication skills']",
#  "['Kotlin Multiplatform.. Experience']",
#  "['Mobile Automation Testing']",
#  "['Fastlane']",
#  "['CI/CD workflows']",
#  "['SwiftUI']",
#  "['Bitbucket']",
#  "['TDD']",
#  "['Android SDK']",
#  "['Good verbal communication skills']",
#  "['RxJava/RxKotlin']",
#  "['Jetpack Compose']",
#  "['Analytics']",
#  "['SLI']",
#  "['SLO']",
#  "['TTR']",
#  "['Toil']",
#  "['Kibana/Grafana']",
#  "['Logstash']",
#  "['Python/Kotlin/Go']",
#  "['Real Time transaction protocols/methods']",
#  "['HTTP']",
#  "['MQTT']",
#  "['UDP']",
#  "['Operability']",
#  "['Resilience']",
#  "['Affirm’s Compute platform infrastructure']",
#  '["Affirm\'s future growth"]',
#  "['Affirm']",
#  "['MapReduce']",
#  "['Relational and NoSQL databases']",
#  "['Data Warehouse solutions']",
#  "['Empathy']",
#  "['Curiosity']",
#  "['Raft and Paxos variants']",
#  "['Build and architect systems']",
#  "['TDDs']",
#  "['Bachelor’s Degree']",
#  "['FP games']",
#  "['FP success']",
#  "['Obj-C']",
#  "['Exceptional problem solving']",
#  "['B.S.']",
#  "['Shipped multiple applications']",
#  "['Experience building frameworks']",
#  "['Addressable Assets']",
#  "['Asset Bundles']",
#  "['WebSockets']",
#  "['MZ development']",
#  "['Linux and Mac OSX operating systems']",
#  "['Android release pipelines']",
#  "['Subversion']",
#  "['Mac OSX']",
#  "['Game Development Cycles']",
#  "['Lua']",
#  "['PHP']",
#  "['Puppet']",
#  "['Ansible']",
#  "['Ship exceptional user experiences']",
#  "['Pragmatic approach']",
#  "['Java/JEE']",
#  "['Fluency']",
#  "['Java Spring']",
#  "['Vert.x']",
#  "['SEO teams']",
#  "['Solana']",
#  "['Ethereum']",
#  "['Blockchain tech']",
#  "['SQL and NoSQL databases']",
#  "['Strong written and verbal communication skills']",
#  "['Apache NiFi.. Golang service best practices']",
#  "['Deployment automation']",
#  "['Webpack']",
#  "['Unix-based operating systems']",
#  "['QA methodologies']",
#  "['CI/CD processes']",
#  "['API test automation']",
#  "['VMs']",
#  "['Linux containers']",
#  "['Perfecto products']",
#  "['Java development experience']",
#  "['Strong proficiency']",
#  "['Java backend infrastructure']",
#  "['NodeJS']",
#  "['AWS platform']",
#  "['B.Sc']",
#  "['Experience designing']",
#  "['RocksDB']",
#  "['Frontend software development']",
#  "['JS ecosystem']",
#  "['SEO principles']",
#  "['UX/user-empathy']",
#  "['Terraform']",
#  "['Comprehensive systems hardware']",
#  "['Common Linux distribution platform installation']",
#  "['TCP/IP networking']",
#  "['NIC bonding and network services configuration']",
#  "['NTP']",
#  "['SMTP']",
#  "['VMware']",
#  "['Hyper-V']",
#  "['KVM']",
#  "['IaaS']",
#  "['PaaS']",
#  "['SaaS']",
#  "['Experience managing networking devices']",
#  "['DevOps tools']",
#  "['NMS']",
#  "['CSS levels']",
#  "['Next.js']",
#  "['UI quality tools']",
#  "['Cloud Service Providers']",
#  "['AWS / Azure / GCP']",
#  "['Kotlin']",
#  "['REST API based products']",
#  "['Strong reasoning']",
#  "['Android dev']",
#  "['JS/AngularJS dev']",
#  "['MVVM']",
#  "['CameraX, Dagger']",
#  "['TensorFlow lite']",
#  "['KMM']",
#  "['Kotlin Multiplatform Mobile']",
#  "['VueJS']",
#  "['Bamboo']",
#  "['API design principles']",
#  "['NoSQL databases']",
#  "['Site Reliability Engineering']",
#  "['SRE']",
#  "['Sonatype']",
#  "['Haskell']",
#  "['Unix-based OS Experience']",
#  "['CI/CD technologies']",
#  "['GitHub Actions']",
#  "['Hadoop']",
#  "['Hive']",
#  "['Jupyter Notebook']",
#  "['Confluence']",
#  "['Dayforce personnel']",
#  "['Med - Large size/complexity']",
#  "['Web Services Protocols']",
#  "['WCF']",
#  "['MVC web frameworks']",
#  "['JavaScript-based web and mobile applications']",
#  "['SaaS products']",
#  "['PowerShell']",
#  "['Azure and cloud-native architecture']",
#  "['CI/CD pipelines']",
#  "['DevOps practices']",
#  "['TSQL and relational database systems']",
#  "['OAuth']",
#  "['OpenID Connect protocols']",
#  "['Multi-factor authentication']",
#  "['Dojo']",
#  "['Backbone']",
#  "['SQL database']",
#  "['TSQL']",
#  "['Agile projects']",
#  "['Azure DevOps Server']",
#  "['CI build process']",
#  "['Azure/AWS cloud platforms']",
#  "['Android or Linux kernels']",
#  "['Android OS']",
#  "['JavaScript frameworks']",
#  "['Kotlin / Kotlin multiplatform']",
#  "['C++ programing']",
#  "['Swift programming expertise']",
#  "['Apple’s HIG']",
#  "['Selenium/Gherkin']",
#  "['Speckflow']",
#  "['Gherkin']",
#  "['Cucumber']",
#  "['Specflow']",
#  "['RDBMS']",
#  "['UI design tradeoffs']",
#  '["Master\'s Degree"]',
#  '["Bachelor\'s Degree Computer Science"]',
#  "['Pillar']",
#  "['AngularJS']",
#  "['ASP.NET']",
#  "['Web API']",
#  "['Dependency Injection']",
#  "['Web Api']",
#  "['Entity Framework/ORM']",
#  "['Multi-Threading']",
#  "['Object Oriented Design skills']",
#  "['Strong written and oral communication skills']",
#  "['Basis Technologies DSP systems']",
#  "['Linux Operating Systems']",
#  "['SaltStack']",
#  "['Bash']",
#  "['Diagnostics']",
#  "['Athena']",
#  "['Glue']",
#  "['Big Query']",
#  "['Dataproc']",
#  "['Dataflow']",
#  "['Google Cloud Platform data technologies']",
#  "['Google BigQuery']",
#  "['Google DataFlow']",
#  "['PySpark']",
#  "['SparkSQL']",
#  "['Spark queries']",
#  "['Conventional RDBMS']",
#  "['BigQuery']",
#  "['Microsoft Azure SQL Data Warehouse']",
#  "['Airflow']",
#  "['Oozie']",
#  "['Luigi']",
#  "['Talend']",
#  "['Pythian']",
#  "['EGSE']",
#  "['Payload throughput']",
#  "['RF and digital equipment']",
#  "['Digital channel processor specifications']",
#  "['Direct Radiating Array (DRA) Antenna']",
#  "['High capacity multiple spot beam systems']",
#  "['Flexible payload']",
#  "['Multi-Port Amplifier']",
#  "['RF and system payload']",
#  "['French fluency']",
#  "['Excellent interpersonal skills']",
#  "['IaC']",
#  "['PCB design']",
#  "['FPGA']",
#  "['RF']",
#  "['Relevant DevOps engineering experience']",
#  "['Groovy']",
#  "['Montréal']",
#  "['Linux system administration']",
#  "['Git/SVN']",
#  "['GitLab']",
#  "['Azure Cloud']",
#  "['Docker and container orchestrators']",
#  "['SQL Databases']",
#  "['TLS']",
#  "['GUI tools']",
#  "['VSphere']",
#  "['VirtualBox']",
#  "['DevOps Engineers']",
#  "['DevOps automation/infrastructure/product delivery']",
#  "['ALM tools']",
#  "['Active Directory']",
#  "['Azure technologies']",
#  "['Compute']",
#  "['SQL/Cosmos/Mongo/PostGreSQL']",
#  "['User journeys']",
#  "['Oracle Siebel']",
#  "['Oracle Policy Automation']",
#  "['Middleware']",
#  "['A bachelor’s degree']",
#  "['Siebel SOAP Structure']",
#  "['WSDLs']",
#  "['XSDs']",
#  "['XSLT']",
#  "['XMLs']",
#  "['Siebel Workflows']",
#  "['Error/Exception Handling']",
#  "['Siebel Integration Object structures']",
#  "['EAI Business Services']",
#  "['Siebel Configuration']",
#  "['SQL / Store procedure creation']",
#  "['Siebel enterprise architecture']",
#  "['Siebel Open UI']",
#  "['Java Script']",
#  "['Siebel Public Sector applications']",
#  "['Technical expertise']",
#  "['Experience designing and developing APIs, web and mobile properties']",
#  "['Scrum']",
#  "['Agile team']",
#  "['Automated testing']",
#  "['Agile development environment']",
#  "['Strong written/verbal communication skills']",
#  "['Bachelor degree']",
#  "['Highly motivated, enthusiastic, and a positive thinker']",
#  "['VxWorks']",
#  "['RTX']",
#  "['RTEMS']",
#  "['Communications interfaces']",
#  "['SPI']",
#  "['EtherCAT']",
#  "['ATDD']",
#  "['BDD']",
#  "['Continuous integration/build automation']",
#  "['Windows Active Directory']",
#  "['Azure AD Connect']",
#  '["Microsoft\'s Active Directory Domain Services"]',
#  "['AD CS']",
#  '["Microsoft\'s Active Directory Federation Services"]',
#  "['AD FS']",
#  "['AD LDS']",
#  '["Microsoft\'s Active Directory Rights Management Services"]',
#  "['RMS']",
#  "['MFA']",
#  "['SSPR']",
#  "['ATA']",
#  "['FIM/MIM']",
#  "['L/L production support']",
#  "['Qualifications']",
#  "['Microsoft Active Directory']",
#  "['Azure AD Zero Trust components implementation']",
#  "['Conditional Access']",
#  "['SAML']",
#  "['Azure AD proxy']",
#  "['Microsoft’s advanced security and networking services']",
#  "['Key Vault']",
#  "['Sentinel']",
#  "['Organization/Folder/Project/Resource structures']",
#  "['Intune']",
#  "['Conditional Access \\\\ MDM \\\\ MAM']",
#  "['Tenant \\\\ Security & Compliance Center']",
#  "['Archiving']",
#  "['M Security & Compliance  Strong PowerShell scripting skills']",
#  "['Microsoft  security and strategy discussions']",
#  "['IaaS/PaaS/SaaS platforms']",
#  "['GCP certifications']",
#  "['Scope Key Candidate Skills']",
#  "['HSM']",
#  "['Integrated DLP']",
#  "['CI/CD systems']",
#  "['Observability']",
#  "['Telemetry tools']",
#  "['Salus']",
#  "['AppSec']",
#  "['A/B testing frameworks']",
#  "['Blockchain technology']",
#  "['Wrapbook customer problems']",
#  "['Mentoring']",
#  "['SQL queries']",
#  "['Rails applications']",
#  "['SQL indices']",
#  "['Agile or Lean environment']",
#  "['Proven mentor']",
#  "['Javascript/Typescript']",
#  "['Ada’s builder experience organization']",
#  "['Ada’s application']",
#  "['Required Qualifications']",
#  "['Hadoop ecosystem']",
#  "['Spark jobs']",
#  "['HiveQL']",
#  "['Hadoop Clusters Proven']",
#  "['Azure ADLS']",
#  "['Linux enviroment']",
#  "['Automation opportunities']",
#  "['Bug fixes']",
#  "['Required Skills Linux Spark']",
#  "['SQL Hadoop Ecosystem - Hive']",
#  "['Tez']",
#  "['Optional Skills Azure Services Python Autosys']",
#  "['Plastic SCM']",
#  "['Helm']",
#  "['AWS products']",
#  "['Excellent written and oral communication skills']",
#  "['QA test procedures']",
#  "['Troubleshooting quality issues']",
#  "['Quality Assurance reports']",
#  "['Automation']",
#  "['Testing Automation']",
#  "['Software Development methodologies']",
#  "['Kubernetes clusters']",
#  "['MTTR']",
#  "['SLO targets']",
#  "['DevOps role']",
#  "['VictoriaMetrics']",
#  "['Datadog']",
#  "['Zabbix']",
#  "['SLIs']",
#  "['SLOs']",
#  "['SAS programming activities']",
#  "['SAS Programming activities']",
#  "['TFL shells']",
#  "['Company generic macro usage']",
#  "['CDISC compliant tabulation']",
#  "['CDISC therapeutic area standards']",
#  "['TFL output']",
#  "['Archive deliverable files']",
#  "['Lead Statistician']",
#  "['Lead Biostatistician and Project Manager']",
#  "['SAS Programming expertise']",
#  "['SAS Programming Subject Matter Expert']",
#  "['Support SAS Programming process improvement']",
#  "['SAS Programming Client Account Manager']",
#  "['SAS Programming']",
#  "['Company SAS Programming services']",
#  "['SAS Programmers']",
#  "['Accurately record time']",
#  "['SAS programming experience']",
#  "['Master’s Degree']",
#  "['CDISC SDTM']",
#  "['ADaM Implementation Guidelines']",
#  "['Excellent organizational skills']",
#  "['Sponsors']",
#  "['Strong Analytical mindset']",
#  "['CDASH']",
#  "['CDISC standards']",
#  "['Annotate case report forms']",
#  "['CRFs']",
#  "['SDTM']",
#  "['SDTM specifications document']",
#  "['CDISC Implementation Guideline']",
#  "['XML documents']",
#  "['Biostatistical programming and Biostatistical staff']",
#  "['SAS code']",
#  "['Listings']",
#  "['Figures outputs']",
#  "['SAS programs']",
#  "['QC SAS programs']",
#  "['Dataset']",
#  "['Train and mentor new hires']",
#  "['Define XML']",
#  "['PDFs']",
#  "['Reviewers Guides']",
#  "['CDISC']",
#  "['Veristat']",
#  "['OR Master’s Degree']",
#  "['Continuous Delivery/Continuous Integration workflow']",
#  "['Python/Go/Bash scripting experience']",
#  "['Strong Linux Systems Administration Experience']",
#  "['Managed Apache Airflow']",
#  "['Kubernetes cluster']",
#  "['Prometheus and PromQL experience']",
#  "['Ansible/Puppet/Chef experience']",
#  "['Concourse/Zuul/Jenkins experience']",
#  "['Code - Terraform']",
#  "['GKE']",
#  "['DevOps best practices']",
#  "['Airflow deployments']",
#  "['Peer AWS']",
#  "['Sqoop']",
#  "['HBase']",
#  "['Impala']",
#  "['Scala Control^M']",
#  "['BSTM']",
#  "['Datahub']",
#  "['Cloud Data platforms']",
#  "['Data Architectures']",
#  "['Hadoop and Data Engineering space']",
#  "['Apache Hadoop distributions']",
#  "['HDFS']",
#  "['Hbase']",
#  "['Flume']",
#  "['Hadoop Framework']",
#  "['HBASE']",
#  "['Workflows']",
#  "['ORC']",
#  "['Parquet']",
#  "['Jira']",
#  "['Continuous Integrations tools']",
#  "['Linux/Mac OS administration']",
#  "['WorkForce Software experience']",
#  "['SAP SuccessFactors']",
#  "['WorkForce Software modules']",
#  "['A Bachelor’s Degree']",
#  "['Xero']",
#  '["You Bachelor\'s Degree"]',
#  "['Nodejs']",
#  "['TestCafe']",
#  "['SeleniumHave']",
#  "['Continuous Integration systems']",
#  "['AWS CodeBuild)Experience']",
#  "['RESTful web services']",
#  "['Agile/Scrum']",
#  "['Lean and Agile ways']",
#  "['M.Sc']",
#  "['Interpersonal and collaboration skills']",
#  "['Assembler']",
#  "['Gerrit']",
#  "['Esper’s flagship Esper Enhanced Android']",
#  "['Esper’s enterprise-grade, security-focused Android OS']",
#  "['Java / Kotlin / Android apps']",
#  "['Android framework internals / device bringups']",
#  "['AOSP']",
#  "['Linux kernel']",
#  "['SELinux']",
#  "['LineageOS']",
#  "['CTS tests']",
#  "['CTS-compliant Android platforms']",
#  "['Triage']",
#  "['Design workflows']",
#  "['TD meetings']",
#  "['Document workflows']",
#  "['Maya and Maya scripting']",
#  "['Nuke and Houdini experience']",
#  "['Object-oriented Python']",
#  "['OSI Model']",
#  "['TCP/IP, LAN switching']",
#  "['IP routing and Ethernet networks']",
#  "['Ixia']",
#  "['ESXI/Hyper-V/KVM']",
#  "['VM']",
#  "['Agile development and testing processes']",
#  "['WLAN advanced security protocols']",
#  "['WPA']",
#  "['WPA']",
#  "['WPA']",
#  "['RADIUS protocol']",
#  "['Selenium']",
#  "['AEM']",
#  "['Sling']",
#  "['AEM Components']",
#  "['Sling Models']",
#  "['OSGi Services']",
#  "['Servlets']",
#  "['Methodical approach']",
#  "['Dialogs']",
#  "['Templates']",
#  "['ClientLibs']",
#  "['ES JavaScript']",
#  "['Storybook.js']",
#  "['CDW offerings']",
#  "['Reviews peer’s designs']",
#  "['Determines']",
#  "['Calc']",
#  "['CDW']",
#  "['CDW audiences']",
#  "['Coaches and mentors team members']",
#  "['FSAs']",
#  "['Advises']",
#  "['ITS Practice (Integrated Technology Solutions) value proposition']",
#  "['CDW.Guides']",
#  "['CDW technologies']",
#  "['McAfee/Juniper']",
#  "['NetApp']",
#  "['CDW customer events']",
#  "['Solution Architects']",
#  "['ISA']",
#  "['AE']",
#  "['ISO']",
#  "['COBIT']",
#  "['Vulnerability Management / Assessment']",
#  "['CISM']",
#  "['GOSU']",
#  "['Dependency management']",
#  "['Gradle']",
#  "['NPM']",
#  "['Nexus']",
#  "['Artifactory']",
#  "['GIT']",
#  "['SVN']",
#  "['AI-enabled metadata management tools']",
#  "['A bachelor']",
#  "['Object-oriented/object function scripting']",
#  "['AWS Redshift']",
#  "['AWS Aurora']",
#  "['SQL Server']",
#  "['ETL/ELT']",
#  "['Amazon Simple queuing Service']",
#  "['Apache Nifi']",
#  "['Apache Kafka Streams']",
#  ...]

# %%
az = []
for i in a:
    if len(i)>5:
        az.append(i)

# %%
import re
q = []
for i in az:
    q.append(re.search(".\b", i))

# %%
kl = []
for i in az:
    print(i)
# Out:
# ['Java Streams']
# ['Object Oriented analysis']
# ['Relational Databases']
# ['SQL']
# ['ORM']
# ['JPA']
# ['Hibernate']
# ['MyBatis']
# ['Git.. Familiarity']
# ['Maven']
# ['Gradle.. Familiarity']
# ['Familiarity']
# ['Demonstrable experience']
# ['Bachelor or Master degree']
# ['STEM majors']
# ['Strong algorithms']
# ['Python']
# ['Scala programming experience']
# ['Exceptional proficiency']
# ['MySQL']
# ['Oracle']
# ['NoSQL Stores']
# ['Clickhouse']
# ['Distributed Processing Engines']
# ['Apache Flink']
# ['Celery']
# ['Distributed Queues']
# ['AWS Kinesis']
# ['GCP PusSub']
# ['GCP']
# ['Azure']
# ['AWS']
# ['Excellent Unix/Linux experience and programming experience']
# ['IPC mechanisms']
# ['TCP/IP']
# ['Kafka']
# ['API gateways']
# ['CAP Theorem']
# ['RAFT']
# ['Paxos']
# ['CI/CD']
# ['Github']
# ['Makefiles']
# ['Microservices']
# ['GCPNode.js']
# ['REST APIs servicesExperience writing tools']
# ['Ruby']
# ['PerlExperience']
# ['Bazel']
# ['HTTP /websocket']
# ['Redis']
# ['Web UIExperience']
# ['JavaScript']
# ['HTML']
# ['CSS']
# ['Angular']
# ['Meteor']
# ['Ember']
# ['Knockout']
# ['UI Component libraries']
# ['Vue']
# ['Bootstrap']
# ['ES']
# ['TypeScript']
# ['Dependency injection patterns']
# ['Async Module Definition']
# ['AMD, requireJS']
# ['Stylesheet languages']
# ['SASS']
# ['Redux']
# ['Reactive Programming']
# ['RxJS']
# ['JavaStrong programming skills']
# ['Guice knowledge']
# ['Protobuf knowledge']
# ['APIs']
# ['Web UI:Deep understanding']
# ['JSON']
# ['JavaScript Design']
# ['Architectural Patterns']
# ['Proficiency']
# ['Spring/Guice']
# ['JPA/Hibernate']
# ['JavaExperience']
# ['Containers knowledge']
# ['Multi-threaded concepts']
# ['NoSQL']
# ['MongoDB']
# ['Cassandra']
# ['Java Application Servers']
# ['Oracle WebLogic']
# ['JBoss']
# ['Tomcat']
# ['Jasmine']
# ['Karma']
# ['Protractor']
# ['Junit']
# ['Cross-browser techniques']
# ['Chrome Dev Tools']
# ['Responsive design implementation']
# ['Browser performance auditing']
# ['Scrum / Kanban']
# ['Guice']
# ['GRPC']
# ['Excellent analytical and problem-solving skills']
# ['Proven-deep-expertise']
# ['Python programming']
# ['Django']
# ['Flask']
# ['Unix / Linux command line']
# ['Object-oriented concepts']
# ['UI frameworks']
# ['Hadoop / Hive / Presto']
# ['ML/AI frameworks']
# ['TensorFlow']
# ['Mesos']
# ['Kubernetes']
# ['Application benchmarking']
# ['Building user interface applications']
# ['UI Applications']
# ['QML']
# ['Qt/C++']
# ['RasPi']
# ['BeagleBone']
# ['IP-based network protocols']
# ['Myntra’s new product platforms']
# ['Architects']
# ['DevOps engineers']
# ['Myntra']
# ['Java/GO']
# ['Developing user-facing web applications']
# ['Bachelor']
# ['Backend services']
# ['React JS']
# ['JS/TypeScript']
# ['Webpack bundling']
# ['Dev tools']
# ['HTML']
# ['CSS']
# ['SCSS']
# ['Mysql']
# ['Postgres']
# ['Data modeling skills']
# ['Detail Design phases']
# ['Minimum  year Java design and development experience']
# ['Spring and Hibernate based solutions']
# ['High-Quality Deliverables']
# ['SOPs']
# ['Checks programming logs']
# ['Inputs']
# ['Handles']
# ['Programs TLFs']
# ['EAC']
# ['BIOSETUP']
# ['SAP']
# ['Shares accountability']
# ['ADaM reviewers guide']
# ['SDRG']
# ['ADRG']
# ['RFPs']
# ["Master's Degree Computer science"]
# ["Bachelor's Degree Computer science"]
# ['CDISC/ADaM/SDTM']
# ['Base SAS']
# ['SAS/STAT']
# ['SAS Macro Language']
# ['Good organizational, interpersonal, leadership and communication skills']
# ['Coda']
# ['ETL']
# ['AWS technologies']
# ['Redshift']
# ['EMR']
# ['EC']
# ['DynamoDB']
# ['Kinesis Firehose']
# ['Lambda']
# ['ML teams']
# ['Tableau']
# ['Bachelor’s degree']
# ['Hadoop/MapReduce/AWS']
# ['Spark/Scala/PySpark/ Apache Kafka / Kinesis Streams / AWS Glue']
# ['Experience building flexible data APIs']
# ['Agile Development']
# ['Collaborative Filtering']
# ['Preferably, apps']
# ['XCode.. Experience']
# ['Multi-threading and performance & memory optimization']
# ['RESTful APIs']
# ['Proficient understanding']
# ['Git']
# ['Rubrik Software Engineers']
# ['Master’s degree']
# ['Scala']
# ['Google Cloud Platform/AWS/Azure']
# ['Unix/Linux environments']
# ['Windows environments']
# ['Kubernetes Service']
# ['RESTful services']
# ['Entity Framework']
# ['Nhibernate']
# ['Strong TDD approach']
# ['Nunit']
# ['OOP and SOLID design principles']
# ['Highly efficient data persistent design techniques']
# ['Proficient experience']
# ['Microsoft SQL Server/Postgres']
# ['Agile practices']
# ['Debugging/Troubleshooting functional and technical issues']
# ['Performance/Optimization techniques']
# ['Excellent analytical, quantitative, and problem-solving abilities']
# ['Strong interpersonal']
# ['Xamarin']
# ['LINQ']
# ['Rest APIs']
# ['Xamarin Forms']
# ['Xamarin Native development']
# ['Xamarin Studio']
# ['Xamarin Apps']
# ['UWP']
# ['XAML']
# ['Azure Active Directory']
# ['Notifications']
# ['HockeyApp/Visual Studio App Center']
# ['Continuous Integration']
# ['CI']
# ['DevOps']
# ['Automation Testing']
# ['Xamarin Profiler']
# ['Various code repositories']
# ['TFS']
# ['MVVM Architecture']
# ['VSTS']
# ['Overall Cross Platform app development ecosystem']
# ['Portable Class Library']
# ['PCL']
# ['SQLite']
# ['Xamarin Binding']
# ['SAP HANA REST API Integration']
# ['Core Java']
# ['Swift / XCode']
# ['CRM']
# ['CMS']
# ['Highspot’s external API']
# ['Highspot’s Salesforce integrations']
# ['UX']
# ['Highspot’s Infrastructure Platform crew']
# ['Highspot']
# ['Highspot’s feature engineering crews']
# ['Clojure']
# ['Node']
# ['Typescript']
# ['Operational efficiencies']
# ['Collaborative build practices']
# ['API']
# ['UI components']
# ['Automated analysis']
# ['UI']
# ['Data annotation']
# ['Degree qualification']
# ['Ideally some exposure']
# ['Workplace Search']
# ['Elasticsearch']
# ['Kibana']
# ['DevOPS']
# ['Self-starter']
# ['SLA']
# ['Strong TCP/IP knowledge']
# ['Proxies']
# ['NG Firewalls']
# ['SSL/IPSec']
# ['VPN']
# ['SSO']
# ['DLP and Encryption gateways']
# ['UNIX/Linux']
# ['Windows\xad based systems']
# ['DNS']
# ['DHCP']
# ['Strong empathy']
# ['Interpersonal Skills']
# ['Zendesk']
# ['Bachelors or Masters degree']
# ['Excellent grasp']
# ['MLOps processes']
# ['SparkML']
# ['NumPy']
# ['Tensorflow']
# ['PyTorch']
# ['Keras']
# ['Spark']
# ['Jenkins']
# ['GNN']
# ['RL']
# ['Recommender Systems']
# ['NLP techniques']
# ['Analyzes']
# ['QA test plans']
# ['SDLC']
# ['Agile']
# ['Micro-services architecture']
# ['OpenShift']
# ['K cluster']
# ['Nginx/Ingres']
# ['API Gateway']
# ['Service Mesh']
# ['TortoiseGit / Sourcetree']
# ['BitBucket']
# ['JIRA']
# ['Mockito']
# ['Application Servers']
# ['WebSphere']
# ['Database Servers']
# ['PostgreSQL']
# ['MSSQL']
# ['Linux']
# ['Object Oriented Programming knowledge']
# ['JAXB']
# ['Apache Commons']
# ['Apache POI']
# ['Eclipse / STS']
# ['XML']
# ['XSD']
# ['Apache Ant']
# ['Linux bash scripting']
# ['DDL']
# ['DML']
# ['JDBC']
# ['Java Message Service']
# ['JMS']
# ['LiveView']
# ['Rails']
# ['API development']
# ['Sinatra']
# ['GitHub']
# ['A strong grasp']
# ['Exq']
# ['Sidekiq']
# ['Beanstalk']
# ['RabbitMQ']
# ['ExUnit']
# ['RSpec']
# ['Jest']
# ['Elixir']
# ['GraphQL APIs']
# ['Absinthe']
# ['GraphQL']
# ['JavaScript SSR']
# ['Willingness']
# ['MySql']
# ['Deployment']
# ['RESTful webservices']
# ['InfluxDB']
# ['Prometheus']
# ['ReactJS']
# ['UI changes']
# ['UI Team']
# ['HTML/CSS/SASS']
# ['QA']
# ['REST APIs']
# ['Mocha']
# ['UX teams']
# ['CI tools']
# ['Dev-Ops Deployment process']
# ['BDD/TDD']
# ['BDD Experience']
# ['RESTFUL API']
# ['Scripting']
# ['Grafana']
# ['NewRelic']
# ['Stackdriver']
# ['Sumo Logic']
# ['CloudWatch']
# ['BS/MS']
# ['Docker']
# ['Perforce']
# ['Android java']
# ['Android Kotlin']
# ['Buck/Bazel']
# ['Golang']
# ['REST/GraphQL']
# ['SQL/NoSQL Databases']
# ['Micronaut']
# ['Quarkus']
# ['NoSQL Databases']
# ['Event Brokers']
# ['FaaS']
# ['Terraform’s open source and commercial offerings']
# ['HashiCorp customers']
# ['Ph.D.']
# ['ML techniques']
# ['SVMs']
# ['Entrepreneurial and positive attitude']
# ['Fortune  companies']
# ["Bachelor's degree"]
# ['Networking']
# ['HTTPS/SSL']
# ['VLANs, TCP/IP']
# ['NAT devices']
# ['DHCP servers']
# ['Firewalls']
# ['Genuine excitement']
# ['IoT']
# ['Industry certifications']
# ['CCNA']
# ['CCDA']
# ['CCNP']
# ['MCSE']
# ['CEH']
# ['Microsoft Azure']
# ['CISSP']
# ['CSP']
# ['Linux systems']
# ['Good theoretical grounding']
# ['Excellent stakeholder communication']
# ['Natural Language ProcessingContent & Context UnderstandingRecommender SystemsGraph / Geometric Deep LearningModel']
# ['NetSuite']
# ['Netsuite ERP - Implementation']
# ['Avalara']
# ['Billing']
# ['ERP']
# ['NetSuite ERP experience']
# ['Salesforce.com']
# ['Javascript']
# ['Unix scripts tool set']
# ['SuiteScript']
# ['SuiteFlows']
# ['Web Services/SuiteTalk']
# ['Exceptional communicator']
# ['NetSuite Administrator Certification']
# ['Bachelors or masters degree']
# ['ERP implementation experience']
# ['Excellent JavaScript development skills']
# ['Node.js ecosystem']
# ['Cloud environments']
# ['React web app development']
# ['UIs']
# ['Experience building API gateways']
# ['CI/CD technology']
# ['Real-time D/D applications']
# ['Mentor']
# ['TPM']
# ['VM/container management']
# ['Proven programming skills']
# ['Node.js']
# ['Demonstrable understanding']
# ['Observance']
# ['Clean architectural and coding principles']
# ['Good problem-solving skills']
# ['Excellent verbal communication skills']
# ['Kotlin Multiplatform.. Experience']
# ['Mobile Automation Testing']
# ['Fastlane']
# ['CI/CD workflows']
# ['SwiftUI']
# ['Bitbucket']
# ['TDD']
# ['Android SDK']
# ['Good verbal communication skills']
# ['RxJava/RxKotlin']
# ['Jetpack Compose']
# ['Analytics']
# ['SLI']
# ['SLO']
# ['TTR']
# ['Toil']
# ['Kibana/Grafana']
# ['Logstash']
# ['Python/Kotlin/Go']
# ['Real Time transaction protocols/methods']
# ['HTTP']
# ['MQTT']
# ['UDP']
# ['Operability']
# ['Resilience']
# ['Affirm’s Compute platform infrastructure']
# ["Affirm's future growth"]
# ['Affirm']
# ['MapReduce']
# ['Relational and NoSQL databases']
# ['Data Warehouse solutions']
# ['Empathy']
# ['Curiosity']
# ['Raft and Paxos variants']
# ['Build and architect systems']
# ['TDDs']
# ['Bachelor’s Degree']
# ['FP games']
# ['FP success']
# ['Obj-C']
# ['Exceptional problem solving']
# ['B.S.']
# ['Shipped multiple applications']
# ['Experience building frameworks']
# ['Addressable Assets']
# ['Asset Bundles']
# ['WebSockets']
# ['MZ development']
# ['Linux and Mac OSX operating systems']
# ['Android release pipelines']
# ['Subversion']
# ['Mac OSX']
# ['Game Development Cycles']
# ['Lua']
# ['PHP']
# ['Puppet']
# ['Ansible']
# ['Ship exceptional user experiences']
# ['Pragmatic approach']
# ['Java/JEE']
# ['Fluency']
# ['Java Spring']
# ['Vert.x']
# ['SEO teams']
# ['Solana']
# ['Ethereum']
# ['Blockchain tech']
# ['SQL and NoSQL databases']
# ['Strong written and verbal communication skills']
# ['Apache NiFi.. Golang service best practices']
# ['Deployment automation']
# ['Webpack']
# ['Unix-based operating systems']
# ['QA methodologies']
# ['CI/CD processes']
# ['API test automation']
# ['VMs']
# ['Linux containers']
# ['Perfecto products']
# ['Java development experience']
# ['Strong proficiency']
# ['Java backend infrastructure']
# ['NodeJS']
# ['AWS platform']
# ['B.Sc']
# ['Experience designing']
# ['RocksDB']
# ['Frontend software development']
# ['JS ecosystem']
# ['SEO principles']
# ['UX/user-empathy']
# ['Terraform']
# ['Comprehensive systems hardware']
# ['Common Linux distribution platform installation']
# ['TCP/IP networking']
# ['NIC bonding and network services configuration']
# ['NTP']
# ['SMTP']
# ['VMware']
# ['Hyper-V']
# ['KVM']
# ['IaaS']
# ['PaaS']
# ['SaaS']
# ['Experience managing networking devices']
# ['DevOps tools']
# ['NMS']
# ['CSS levels']
# ['Next.js']
# ['UI quality tools']
# ['Cloud Service Providers']
# ['AWS / Azure / GCP']
# ['Kotlin']
# ['REST API based products']
# ['Strong reasoning']
# ['Android dev']
# ['JS/AngularJS dev']
# ['MVVM']
# ['CameraX, Dagger']
# ['TensorFlow lite']
# ['KMM']
# ['Kotlin Multiplatform Mobile']
# ['VueJS']
# ['Bamboo']
# ['API design principles']
# ['NoSQL databases']
# ['Site Reliability Engineering']
# ['SRE']
# ['Sonatype']
# ['Haskell']
# ['Unix-based OS Experience']
# ['CI/CD technologies']
# ['GitHub Actions']
# ['Hadoop']
# ['Hive']
# ['Jupyter Notebook']
# ['Confluence']
# ['Dayforce personnel']
# ['Med - Large size/complexity']
# ['Web Services Protocols']
# ['WCF']
# ['MVC web frameworks']
# ['JavaScript-based web and mobile applications']
# ['SaaS products']
# ['PowerShell']
# ['Azure and cloud-native architecture']
# ['CI/CD pipelines']
# ['DevOps practices']
# ['TSQL and relational database systems']
# ['OAuth']
# ['OpenID Connect protocols']
# ['Multi-factor authentication']
# ['Dojo']
# ['Backbone']
# ['SQL database']
# ['TSQL']
# ['Agile projects']
# ['Azure DevOps Server']
# ['CI build process']
# ['Azure/AWS cloud platforms']
# ['Android or Linux kernels']
# ['Android OS']
# ['JavaScript frameworks']
# ['Kotlin / Kotlin multiplatform']
# ['C++ programing']
# ['Swift programming expertise']
# ['Apple’s HIG']
# ['Selenium/Gherkin']
# ['Speckflow']
# ['Gherkin']
# ['Cucumber']
# ['Specflow']
# ['RDBMS']
# ['UI design tradeoffs']
# ["Master's Degree"]
# ["Bachelor's Degree Computer Science"]
# ['Pillar']
# ['AngularJS']
# ['ASP.NET']
# ['Web API']
# ['Dependency Injection']
# ['Web Api']
# ['Entity Framework/ORM']
# ['Multi-Threading']
# ['Object Oriented Design skills']
# ['Strong written and oral communication skills']
# ['Basis Technologies DSP systems']
# ['Linux Operating Systems']
# ['SaltStack']
# ['Bash']
# ['Diagnostics']
# ['Athena']
# ['Glue']
# ['Big Query']
# ['Dataproc']
# ['Dataflow']
# ['Google Cloud Platform data technologies']
# ['Google BigQuery']
# ['Google DataFlow']
# ['PySpark']
# ['SparkSQL']
# ['Spark queries']
# ['Conventional RDBMS']
# ['BigQuery']
# ['Microsoft Azure SQL Data Warehouse']
# ['Airflow']
# ['Oozie']
# ['Luigi']
# ['Talend']
# ['Pythian']
# ['EGSE']
# ['Payload throughput']
# ['RF and digital equipment']
# ['Digital channel processor specifications']
# ['Direct Radiating Array (DRA) Antenna']
# ['High capacity multiple spot beam systems']
# ['Flexible payload']
# ['Multi-Port Amplifier']
# ['RF and system payload']
# ['French fluency']
# ['Excellent interpersonal skills']
# ['IaC']
# ['PCB design']
# ['FPGA']
# ['RF']
# ['Relevant DevOps engineering experience']
# ['Groovy']
# ['Montréal']
# ['Linux system administration']
# ['Git/SVN']
# ['GitLab']
# ['Azure Cloud']
# ['Docker and container orchestrators']
# ['SQL Databases']
# ['TLS']
# ['GUI tools']
# ['VSphere']
# ['VirtualBox']
# ['DevOps Engineers']
# ['DevOps automation/infrastructure/product delivery']
# ['ALM tools']
# ['Active Directory']
# ['Azure technologies']
# ['Compute']
# ['SQL/Cosmos/Mongo/PostGreSQL']
# ['User journeys']
# ['Oracle Siebel']
# ['Oracle Policy Automation']
# ['Middleware']
# ['A bachelor’s degree']
# ['Siebel SOAP Structure']
# ['WSDLs']
# ['XSDs']
# ['XSLT']
# ['XMLs']
# ['Siebel Workflows']
# ['Error/Exception Handling']
# ['Siebel Integration Object structures']
# ['EAI Business Services']
# ['Siebel Configuration']
# ['SQL / Store procedure creation']
# ['Siebel enterprise architecture']
# ['Siebel Open UI']
# ['Java Script']
# ['Siebel Public Sector applications']
# ['Technical expertise']
# ['Experience designing and developing APIs, web and mobile properties']
# ['Scrum']
# ['Agile team']
# ['Automated testing']
# ['Agile development environment']
# ['Strong written/verbal communication skills']
# ['Bachelor degree']
# ['Highly motivated, enthusiastic, and a positive thinker']
# ['VxWorks']
# ['RTX']
# ['RTEMS']
# ['Communications interfaces']
# ['SPI']
# ['EtherCAT']
# ['ATDD']
# ['BDD']
# ['Continuous integration/build automation']
# ['Windows Active Directory']
# ['Azure AD Connect']
# ["Microsoft's Active Directory Domain Services"]
# ['AD CS']
# ["Microsoft's Active Directory Federation Services"]
# ['AD FS']
# ['AD LDS']
# ["Microsoft's Active Directory Rights Management Services"]
# ['RMS']
# ['MFA']
# ['SSPR']
# ['ATA']
# ['FIM/MIM']
# ['L/L production support']
# ['Qualifications']
# ['Microsoft Active Directory']
# ['Azure AD Zero Trust components implementation']
# ['Conditional Access']
# ['SAML']
# ['Azure AD proxy']
# ['Microsoft’s advanced security and networking services']
# ['Key Vault']
# ['Sentinel']
# ['Organization/Folder/Project/Resource structures']
# ['Intune']
# ['Conditional Access \\ MDM \\ MAM']
# ['Tenant \\ Security & Compliance Center']
# ['Archiving']
# ['M Security & Compliance  Strong PowerShell scripting skills']
# ['Microsoft  security and strategy discussions']
# ['IaaS/PaaS/SaaS platforms']
# ['GCP certifications']
# ['Scope Key Candidate Skills']
# ['HSM']
# ['Integrated DLP']
# ['CI/CD systems']
# ['Observability']
# ['Telemetry tools']
# ['Salus']
# ['AppSec']
# ['A/B testing frameworks']
# ['Blockchain technology']
# ['Wrapbook customer problems']
# ['Mentoring']
# ['SQL queries']
# ['Rails applications']
# ['SQL indices']
# ['Agile or Lean environment']
# ['Proven mentor']
# ['Javascript/Typescript']
# ['Ada’s builder experience organization']
# ['Ada’s application']
# ['Required Qualifications']
# ['Hadoop ecosystem']
# ['Spark jobs']
# ['HiveQL']
# ['Hadoop Clusters Proven']
# ['Azure ADLS']
# ['Linux enviroment']
# ['Automation opportunities']
# ['Bug fixes']
# ['Required Skills Linux Spark']
# ['SQL Hadoop Ecosystem - Hive']
# ['Tez']
# ['Optional Skills Azure Services Python Autosys']
# ['Plastic SCM']
# ['Helm']
# ['AWS products']
# ['Excellent written and oral communication skills']
# ['QA test procedures']
# ['Troubleshooting quality issues']
# ['Quality Assurance reports']
# ['Automation']
# ['Testing Automation']
# ['Software Development methodologies']
# ['Kubernetes clusters']
# ['MTTR']
# ['SLO targets']
# ['DevOps role']
# ['VictoriaMetrics']
# ['Datadog']
# ['Zabbix']
# ['SLIs']
# ['SLOs']
# ['SAS programming activities']
# ['SAS Programming activities']
# ['TFL shells']
# ['Company generic macro usage']
# ['CDISC compliant tabulation']
# ['CDISC therapeutic area standards']
# ['TFL output']
# ['Archive deliverable files']
# ['Lead Statistician']
# ['Lead Biostatistician and Project Manager']
# ['SAS Programming expertise']
# ['SAS Programming Subject Matter Expert']
# ['Support SAS Programming process improvement']
# ['SAS Programming Client Account Manager']
# ['SAS Programming']
# ['Company SAS Programming services']
# ['SAS Programmers']
# ['Accurately record time']
# ['SAS programming experience']
# ['Master’s Degree']
# ['CDISC SDTM']
# ['ADaM Implementation Guidelines']
# ['Excellent organizational skills']
# ['Sponsors']
# ['Strong Analytical mindset']
# ['CDASH']
# ['CDISC standards']
# ['Annotate case report forms']
# ['CRFs']
# ['SDTM']
# ['SDTM specifications document']
# ['CDISC Implementation Guideline']
# ['XML documents']
# ['Biostatistical programming and Biostatistical staff']
# ['SAS code']
# ['Listings']
# ['Figures outputs']
# ['SAS programs']
# ['QC SAS programs']
# ['Dataset']
# ['Train and mentor new hires']
# ['Define XML']
# ['PDFs']
# ['Reviewers Guides']
# ['CDISC']
# ['Veristat']
# ['OR Master’s Degree']
# ['Continuous Delivery/Continuous Integration workflow']
# ['Python/Go/Bash scripting experience']
# ['Strong Linux Systems Administration Experience']
# ['Managed Apache Airflow']
# ['Kubernetes cluster']
# ['Prometheus and PromQL experience']
# ['Ansible/Puppet/Chef experience']
# ['Concourse/Zuul/Jenkins experience']
# ['Code - Terraform']
# ['GKE']
# ['DevOps best practices']
# ['Airflow deployments']
# ['Peer AWS']
# ['Sqoop']
# ['HBase']
# ['Impala']
# ['Scala Control^M']
# ['BSTM']
# ['Datahub']
# ['Cloud Data platforms']
# ['Data Architectures']
# ['Hadoop and Data Engineering space']
# ['Apache Hadoop distributions']
# ['HDFS']
# ['Hbase']
# ['Flume']
# ['Hadoop Framework']
# ['HBASE']
# ['Workflows']
# ['ORC']
# ['Parquet']
# ['Jira']
# ['Continuous Integrations tools']
# ['Linux/Mac OS administration']
# ['WorkForce Software experience']
# ['SAP SuccessFactors']
# ['WorkForce Software modules']
# ['A Bachelor’s Degree']
# ['Xero']
# ["You Bachelor's Degree"]
# ['Nodejs']
# ['TestCafe']
# ['SeleniumHave']
# ['Continuous Integration systems']
# ['AWS CodeBuild)Experience']
# ['RESTful web services']
# ['Agile/Scrum']
# ['Lean and Agile ways']
# ['M.Sc']
# ['Interpersonal and collaboration skills']
# ['Assembler']
# ['Gerrit']
# ['Esper’s flagship Esper Enhanced Android']
# ['Esper’s enterprise-grade, security-focused Android OS']
# ['Java / Kotlin / Android apps']
# ['Android framework internals / device bringups']
# ['AOSP']
# ['Linux kernel']
# ['SELinux']
# ['LineageOS']
# ['CTS tests']
# ['CTS-compliant Android platforms']
# ['Triage']
# ['Design workflows']
# ['TD meetings']
# ['Document workflows']
# ['Maya and Maya scripting']
# ['Nuke and Houdini experience']
# ['Object-oriented Python']
# ['OSI Model']
# ['TCP/IP, LAN switching']
# ['IP routing and Ethernet networks']
# ['Ixia']
# ['ESXI/Hyper-V/KVM']
# ['VM']
# ['Agile development and testing processes']
# ['WLAN advanced security protocols']
# ['WPA']
# ['WPA']
# ['WPA']
# ['RADIUS protocol']
# ['Selenium']
# ['AEM']
# ['Sling']
# ['AEM Components']
# ['Sling Models']
# ['OSGi Services']
# ['Servlets']
# ['Methodical approach']
# ['Dialogs']
# ['Templates']
# ['ClientLibs']
# ['ES JavaScript']
# ['Storybook.js']
# ['CDW offerings']
# ['Reviews peer’s designs']
# ['Determines']
# ['Calc']
# ['CDW']
# ['CDW audiences']
# ['Coaches and mentors team members']
# ['FSAs']
# ['Advises']
# ['ITS Practice (Integrated Technology Solutions) value proposition']
# ['CDW.Guides']
# ['CDW technologies']
# ['McAfee/Juniper']
# ['NetApp']
# ['CDW customer events']
# ['Solution Architects']
# ['ISA']
# ['AE']
# ['ISO']
# ['COBIT']
# ['Vulnerability Management / Assessment']
# ['CISM']
# ['GOSU']
# ['Dependency management']
# ['Gradle']
# ['NPM']
# ['Nexus']
# ['Artifactory']
# ['GIT']
# ['SVN']
# ['AI-enabled metadata management tools']
# ['A bachelor']
# ['Object-oriented/object function scripting']
# ['AWS Redshift']
# ['AWS Aurora']
# ['SQL Server']
# ['ETL/ELT']
# ['Amazon Simple queuing Service']
# ['Apache Nifi']
# ['Apache Kafka Streams']
# ['Amazon Kinesis']
# ['Apache Kafka KSQL']
# ['BI software tools']
# ['MicroStrategy']
# ['Qlik']
# ['PowerBI']
# ['KNIME']
# ['Alteryx']
# ['AWS Elastic Container Service']
# ['SOC management']
# ['SIEM elements']
# ['Normalization']
# ['Correlation']
# ['Aggregation']
# ['IDS/IPS']
# ['DLP']
# ['Anti-Virus/Endpoint Protection']
# ['Akamai Web Application Security']
# ['Web Application Firewall security solutions']
# ['Azure DevOps']
# ['AKS']
# ['PCF']
# ['Aqua Security platform']
# ['PCI DSS']
# ['SIEM']
# ['Firewall']
# ['Web Proxy']
# ['WAF.. Expert']
# ['Strong Authentication']
# ['Web Content Filtering']
# ['IAM']
# ['Wi-Fi.. Ability']
# ['The incumbent']
# ['Unix/Linux']
# ['SSH']
# ['FTP']
# ['SSL']
# ['Modern Azure PaaS development']
# ['Azure Functions']
# ['Azure DevOps experience']
# ['YAML']
# ['Azure AD Identity']
# ['BB']
# ['BC']
# ['An enthusiastic and self-motivated individual']
# ['Excellent verbal and written communication skills']
# ['Excellent customer relation and communication skills']
# ['Proactive, curious, investigative mindset']
# ['Microsoft Certifications']
# ['Brainstorm']
# ['Frontend Frameworks']
# ['Appium']
# ['EE Smart Devices']
# ['EE architecture']
# ['API design']
# ['Mentor junior developer']
# ['BS Degree']
# ['CS']
# ['Firefox']
# ['Rust']
# ['A meticulous approach']
# ['Python.. Design']
# ['API tests']
# ['PyTest']
# ['In-Sprint Automation']
# ['Azure Devops pipelines']
# ['Blazemeter/JMeter']
# ['Agile ceremonies']
# ['Devs']
# ['Strong coding experience']
# ['Selenium WebDriver']
# ['SQL Server.. Postman']
# ['Swagger']
# ['Blazemeter']
# ['JMeter']
# ['SAS Graph']
# ['Dell Boomi']
# ['SAP CPI']
# ['API technical architecture principles']
# ['API Management']
# ['API Microservices concepts']
# ['ERP systems']
# ['SuccessFactors']
# ['Ariba']
# ['Fieldglass']
# ['Salesforce']
# ['Jira and Agile project development environments']
# ['Integration Standardization practices']
# ['LogicMonitor']
# ["LogicMonitor's business growth"]
# ['SQS']
# ['SQL / NoSQL database knowledge']
# ['Redshift ElasticSearch']
# ['Aurora']
# ['Test frameworks']
# ['JUnit']
# ['WireMock']
# ['AWS services']
# ['RDS']
# ['S etc']
# ['Python experience']
# ['Atlassian Suite']
# ['SNMP']
# ['TCP']
# ['SMI-S']
# ['FluentD']
# ['Netflow']
# ['IOPS']
# ['Accenture Google Business Group’s close-knit, vibrant community']
# ['Accenture’s certified Google Fellows']
# ['Enterprise Data Warehouse technologies']
# ['GCP Cloud data implementation projects experience']
# ['Cloud Composer']
# ['MS SQL Server']
# ['Netezza']
# ['Teradata']
# ['Java Development w/Spring Boot']
# ['Angular Development']
# ['Kafka Producers']
# ['Mongo DB']
# ['Python/Airflow experience']
# ['ASP.Net']
# ['Scrum masters']
# ['B.E./B.Tech/M.S./M.Tech/MCA/MBA']
# ['Hyperion']
# ['Oracle EPBCS']
# ['OneStream']
# ['OneStream Implementation/ Support experience']
# ['VB.NET']
# ['Excellent verbal, written and cross-group collaboration and communication skills']
# ["Bachelor's/Master's degree"]
# ["Industrious' overall systems architecture"]
# ['Industrious’ members']
# ['Typescript Frontend']
# ['ReactJS framework']
# ['Frontend unit testing']
# ['Work ethic']
# ['ExpressJS']
# ['NestJS']
# ['ML engineers']
# ['ML']
# ['DevOps environment']
# ['ETL/ELT processes']
# ['ML processes']
# ['API first systems']
# ['Node.js, object-oriented programming']
# ['MVC applications']
# ['Hands-on experience designing/developing/consuming APIs']
# ['AWS experience']
# ['Zynga-wide technical vision']
# ['Follow engineering standard methodologies']
# ['Zynga games']
# ['Containers']
# ['EKS']
# ['GoLang']
# ['Strong familiarity']
# ['Istio']
# ['EE Mobile Calling']
# ['Android or iOS experience']
# ['CI pipelines']
# ['CD methodologies']
# ['Web development workflows']
# ['JavaScript/Typescript']
# ['Agile development methodologies']
# ['CI/CD infrastructure']
# ['CS/Engineering']
# ['Relay']
# ['Typescript/ES']
# ['Less/Sass']
# ['Jest/Enzyme or equivalent tools']
# ['Vue.js']
# ['Kotlin, Swift']
# ['OIQ']
# ['Lead SRE activities']
# ['SaaS systems']
# ['Liaise']
# ['AWS cloud']
# ['DevOps culture']
# ['CI/CD practices']
# ['CloudFormation']
# ['MLOps tools']
# ['KubeFlow']
# ['MLFlow']
# ['Single Page Application Frameworks']
# ['Sass']
# ['Node.js  NPM']
# ['Yarn']
# ['Gatsby']
# ['Nuxt']
# ['EE']
# ['Hybris components']
# ['SMEs']
# ['Hybris-based technology']
# ['Hybris-based systems']
# ['Bounteous’ Managed Services team']
# ['Hybris services']
# ['Bounteous']
# ['SAP Hybris experience']
# ['Datahub expertise']
# ['Agile Scrum']
# ['Strong interpersonal skills']
# ['Excellent security mindset']
# ['CPQ']
# ['AWS Cloud environment']
# ['BA/BS']
# ['ML applications']
# ['Ember.js']
# ['Backend applications']
# ['Node)Frontend applications']
# ['Some latitude']
# ['Assist or mentor other less experienced team members']
# ['Undergraduate degree']
# ['Thorough understanding']
# ['JS']
# ['SOLID, object-oriented design']
# ['Web Sockets']
# ['STS']
# ['Slalom’s Salesforce Enterprise Architecture capability']
# ['CRM experience']
# ['Strong verbal and written communication skills']
# ['Entrepreneurial spirit']
# ['Javascript bundlers']
# ['React internals']
# ['Object-Oriented programming']
# ['Comfortability']
# ['Agile methods']
# ['XP']
# ['Kanban']
# ['Professional Engineer and PMP certifications']
# ['Keen business acumen']
# ['Utilize test']
# ['Designing']
# ['Coding']
# ['Support Geotab global strategic initiatives']
# ['Post-Secondary Diploma/Degree specialization']
# ['Node.js.. Experience']
# ['Swagger/Yaml REST API interface design']
# ['API specification']
# ['Google Compute Engine']
# ['SQL Server and Postgres database design']
# ['UI/UX design']
# ['Strong analytical skills']
# ['Technical competence']
# ['Docs']
# ['Slides']
# ['Entrepreneurial mindset']
# ['Angular, React']
# ['SQL database design']
# ['MVC']
# ['Cloud computing experience']
# ['GC']
# ['SME']
# ['UI/UX designers']
# ['The DevOps Engineer']
# ['Kubernetes infrastructure']
# ['Google Kubernetes Engine']
# ['Geotab']
# ['Enterprise wide strategic initiatives']
# ['Pre-production Acceptance Testing']
# ['System troubleshooting']
# ['Geotab’s DevOps team']
# ['DevOps standards']
# ['Post-Secondary Degree/Diploma Specialization']
# ['Google Cloud Certified']
# ['Professional Cloud Architect']
# ['AWS Certified Cloud Practitioner']
# ['MCSA Windows Server Certification']
# ['Kubernetes\\OpenShift']
# ['VPC']
# ['KMS']
# ['Cloud Pub/Sub']
# ['Google GCP environment']
# ['Hashicorp tools']
# ['Vault']
# ['CI/CD tools']
# ['Gitlab CI/CD']
# ['Strong scripting']
# ['Apache Kafka']
# ['Flink']
# ['Guide Junior Developers']
# ['Scrum Masters']
# ['Coordinate setup']
# ['CICD pipelines']
# ['Microsoft SQL']
# ['Agile framework']
# ['Solutions Architect']
# ['Single Page Java web applications']
# ['Angular UI']
# ['Strong OO architecture']
# ['Object-Oriented Programming']
# ['Spring BOOT backend REST services']
# ['Angular UI applications']
# ['RDBMS databases']
# ['DB']
# ['Oracle Http Web server']
# ['Oracle WebLogic application server/Tomcat']
# ['Spring framework / Spring Boot']
# ['JPA / Hibernate']
# ['REST API']
# ['Spring Cloud\u202f(Microservices']
# ['Message Queue']
# ['NoSql']
# ['CSS/SCSS']
# ['Angular/React/Vue framework']
# ['OOP and Design Pattern']
# ['SOA']
# ['Hibernate/JPA/MyBatis']
# ['MQ Message']
# ['RabbitMQ/Kafka']
# ['JUnit/TestNG']
# ['BSCS or related field']
# ['MSCS']
# ['CKA/CKAD certification']
# ['Helm experience']
# ['GCE']
# ['Python expertise']
# ['Firmware development']
# ['Experience programming microcontrollers']
# ['ARM Cortex-M experience']
# ['Scripting languages']
# ['API specifications']
# ['WiFi']
# ['Bluetooth']
# ['Zigbee']
# ['GUI application development']
# ['C++ GUI toolkit']
# ['FreeRTOS']
# ['ARM Cortex-M. Experience']
# ['Molex’s Industry . SaaS suite']
# ['SPA']
# ['Object-Oriented Programming concepts']
# ['Excellent problem-solving skills']
# ['Excellent written and verbal communication skills']
# ['IoT technologies']
# ['Nrgx']
# ['Vuex']
# ['Agile Scrum method']
# ['Java/Open Source Technologies']
# ['Software Algorithm Design']
# ['Software Performance Tuning']
# ['Software Debugging']
# ['Software Development Fundamentals']
# ['Agile – Scrum']
# ['Scrum Master']
# ['Object-Oriented design skills']
# ['CI-CD pipelines']
# ['Serverless computing']
# ['OWASP Top']
# ['Git-based code versioning tools']
# ['Prevent alerts']
# ['Speechmatics']
# ['Speechmatics infrastructure']
# ['Unifying deployment methodologies']
# ['Migrating legacy VM based deployments']
# ['Zen learners']
# ['Zen Learners']
# ['Scheduling follow-ups']
# ['Non-tech background learners']
# ["GUVI'S syllabus"]
# ['Angular/React.js']
# ['DOM manipulation']
# ['EcmaScript standards']
# ['React.js']
# ['Flux']
# ['JSX']
# ['Babel.. Experience']
# ['Babel']
# ['Heroku']
# ['Tailwind CSS']
# ['AWS cloud tools']
# ['Dockers']
# ['NodeJs']
# ['Kafka/Resque']
# ['CI/CD pipeline software/tools']
# ['Jenkins..  Experience']
# ['Your workload']
# ['Hadoop Big Data']
# ['Hadoop functioning']
# ['UWQ']
# ['Cloud deployment']
# ['SECS/GEM']
# ['Business Intelligence Architect']
# ['Business Analysts']
# ['Vulcan’s data platform']
# ['ERP software design']
# ['IVR Services']
# ['Coursework']
# ['JEE']
# ['JSF']
# ['Web . technologies']
# ['RESTful API Modeling Language']
# ['RAML']
# ['Java Enterprise Applications']
# ['SQL Server Integration Services']
# ['SSIS']
# ['SSRS']
# ['QA process']
# ['Proven problem-solving abilities']
# ['Strong and effective inter-personal and communication skills']
# ['RCA']
# ['ME/M.Tech/MS degree']
# ['Solid proficiency']
# ['REST based APIs']
# ['Algorithms']
# ['Problem solving']
# ['Computer Science Fundamentals']
# ['FinTech domain']
# ['Agile scrum methodologies']
# ['DevOps processes']
# ['Version tools']
# ['REST frameworks']
# ['Core Java development experience']
# ['Core Java concepts']
# ['Sybase']
# ['UDB']
# ['Javascript applications']
# ['CSS']
# ['B.Tech./B.E./M.Tech./MCA']
# ['Java/Scala']
# ['Hadoop/Spark']
# ['ETLs']
# ['RDBMS and/or NoSQL database technologies']
# ['MLOps']
# ['A good grounding']
# ['Sonar']
# ['CI/CD principles']
# ['React/Angular frameworks']
# ['Financial Services and/or Software Consulting experience']
# ['Onboarding or Technical Consultant']
# ['Strong business acumen']
# ['Extensive latitude']
# ['Expert level Java programming skills']
# ['React/Angular']
# ['Agile Project development methodology']
# ['Presentation and mentoring skills']
# ['Provision infrastructure']
# ['DevOps technologies']
# ['Java Swing']
# ['TDD/BDD']
# ['Object Oriented Design']
# ['OOD']
# ['OOP']
# ['Unified Modeling Language']
# ['UML']
# ['Scaled Agile environment']
# ['Configuration Management systems']
# ['Defect Tracking tools']
# ['Debuggers']
# ['Xray']
# ["Bachelor's / Graduation / Equivalent"]
# ['Prototype creative solutions']
# ['Mentor junior members']
# ['Spring MVC frameworks']
# ['HTML/CSS/JavaScript/jQuery']
# ['UI automated tests']
# ['Outstanding problem-solving skills']
# ['Dedication']
# ['A collaborative, team orientated attitude']
# ['Java software development']
# ['API development experience']
# ['Splunk']
# ['Microservices architecture added value']
# ['JWT']
# ['Authentication']
# ['Pods']
# ['Meshes']
# ['Snowflake']
# ['Jenkins Build']
# ['Very good verbal and written communication']
# ['Java-based services']
# ['Oracle Commerce']
# ['ATG']
# ['Java EE']
# ['JEE']
# ['EJB']
# ['JSP']
# ['Advanced proficiency']
# ['ML frameworks']
# ['NLP']
# ['Transformer']
# ['HCM Machine Learning Engineers']
# ['HCM ML']
# ['HCM ML features']
# ['REST API calls']
# ["Workday's object oriented XpressO development environment"]
# ['Workday business logic']
# ['ML backend']
# ['MS/PhD']
# ['Good grasp']
# ['SDET teams']
# ["Workday's proprietary software"]
# ["Bachelor's Degree"]
# ['JVM']
# ['NuGet Development']
# ['Azure Development']
# ['Octopus CD']
# ['QA processes']
# ['EY security systems']
# ['Point Firewall']
# ['Firewall automation platformZscaler Cloud']
# ['SAML Integrations']
# ['Azure ADSonicWall/Pulse Secure/Prisma VPN']
# ['IPv']
# ['Security related Professional qualifications']
# ['Blue Coat BCCPA']
# ['Service management qualifications']
# ['Leverage test automation']
# ['CI/CD objectives']
# ['Quality assurance experience']
# ['JavaScript automation framework']
# ['FFN Talks']
# ['Kubernetes community']
# ["Bachelors' degree"]
# ['Microsoft Defender product']
# ['Research new security vulnerability patterns']
# ['MSRC']
# ['Static Analysis']
# ['Accessibility']
# ['Bachelors']
# ['MacOS']
# ['Security Researcher']
# ['Penetration Tester']
# ['Security Assurance- OR - Academic equivalent experience']
# ['Malware Researchers']
# ['Experience authoring detections']
# ['Secure Development Lifecycle']
# ['SDL']
# ['Good general Linux & networking troubleshooting skills']
# ['A collaborative approach']
# ['Automation/tooling knowledge']
# ['Consul']
# ['Strong technical documentation skills']
# ['A compassionate approach']
# ['Perl']
# ['KPIs']
# ['Azure DevOps & Developing templates']
# ['Docker Swarm']
# ['PowerShell / Perl / Ruby / Python']
# ['Intelligence/Data-warehousing products']
# ['Informatica products']
# ['Maven/Ant']
# ['New Relic']
# ['MS Azure DevOps Engineer Expert']
# ['DevOps Specialist']
# ['Azure PaaS']
# ['Azure storage solutions']
# ['App Gateway']
# ['KeyVaults']
# ['Fortify']
# ['SonarQube']
# ['DevSecOps security practices']
# ['SSL certificate updates']
# ['Deloitte security standards']
# ['VigilantShield']
# ['HP Fortify']
# ['SCA']
# ['Qualys']
# ['IPsec']
# ['VPNs']
# ['LAN/WAN connectivity']
# ['CICD']
# ['Agile, Lean']
# ['Linux development environments']
# ['MS SQL']
# ['Computer Science or Software Engineering disciplines']
# ['Hinge Health software engineers']
# ['Hinge Health applications']
# ['Domain Expertise']
# ['React Native or similar cross-platform mobile development tools']
# ['Problem Solving']
# ['Business intuition']
# ['Clear, inclusive communication']
# ['Full Stack Mobile']
# ['React Native and significant experience']
# ['Security metrics delivery']
# ['CCPA compliance management']
# ['Strong analytical thinking']
# ['OWASP Top  security risks']
# ["API's a plus"]
# ['AWS Sagemaker']
# ['Scrum techniques']
# ['Billtrust']
# ['Mastery']
# ['CSS/Sass, Angular/Javascript']
# ['Agile techniques']
# ['NUnit']
# ['NoSQL data stores']
# ['Well-honed skills']
# ['Agile/SCRUM SDLC']
# ['Kubeflow']
# ['Azure SQL Datawarehouse']
# ['Azure Data Lake']
# ['Azure Databricks']
# ['Cosmos DB']
# ['Azure data migration patterns']
# ['Agile methodology experience']
# ['Customer/client-facing consulting skills']
# ['Proven experience managing projects']
# ['Leverage experience developing software']
# ['Agile/Scrum SDLC']
# ['Agile environment']
# ['Salesforce Marketing Cloud']
# ['Braze']
# ['Google Analytics']
# ['Movable Ink']
# ['SFTP']
# ['Webhooks']
# ['Quality Assurance and data validation procedures']
# ['Martech data engineering']
# ['ETL pipelines']
# ['SOAP APIs']
# ['Leanplum']
# ['Google Analytics Experience']
# ['Comfortable communicating technical/complex information']
# ['KS']
# ['ElasticSearch']
# ['Visualforce']
# ['Apex']
# ['Salesforce sales cloud and service cloud experience']
# ['Salesforce Domain Architect certifications']
# ['MuleSoft']
# ['Snaplogic']
# ['Workato']
# ['SaaS data models']
# ['Authorization or Access delegation tools']
# ['Strong Backend experience']
# ['Erlang']
# ['Multi Factor Authorization experience']
# ['Functional programming']
# ['Ideally Elixir']
# ['React Framework']
# ['Disciplined approach']
# ['GraphQL and/or Apollo Client']
# ['Strong Backend Elixir experience']
# ['Frontend experience']
# ['Clear communication and documentation skills']
# ['Apollo']
# ['Integration and API experience']
# ['Twilio']
# ['Agile and Scrum methodologies']
# ['SFDC development']
# ['Sales/Marketing and Service modules']
# ['Salesforce Certified Platform Developer I']
# ['Certified Platform Developer II Certifications']
# ['Apex Triggers']
# ['Apex Classes']
# ['LWC']
# ['SOQL queries']
# ['SFDC']
# ['Zuora']
# ['Eloqua']
# ['Excellent problem-solving, analytical and investigative skills']
# ['Enterprise application/integration experience']
# ['Tier- level support/Application troubleshooting experience']
# ['Excellent work ethic']
# ['Web Service/Rest API/SOAP API integration experience']
# ['JBOSS/Web/Server hosting platform background']
# ['Boomi platform experience']
# ['ELK']
# ['TICK']
# ['SolarWinds']
# ['AppDynamics']
# ['Database user background - Oracle/MySQL/MSSQL/PostgreSQL']
# ['SQL Queries']
# ['Scripting - PowerShell/Batch/Python/bash']
# ['Confluent Cloud experience']
# ['Webservices']
# ['API integrations']
# ['Agile, ITIL']
# ['Waterfall']
# ['Salesforce certifications']
# ['Product Roadmap']
# ['Technical fluency']
# ['Desired Technical Proficiencies']
# ['Instructional design experience']
# ['Markdown']
# ['Agile project management']
# ['Linux administration']
# ['CentOS / RHEL']
# ['Bash / Python']
# ['Intermediate knowledge']
# ['Observability tools']
# ['Logicmonitor/Grafana/Prometheus']
# ['Elastic/Splunk']
# ['New Relic/AppDynamics']
# ['APM']
# ['Advanced troubleshooting']
# ['Containerize applications']
# ['CI/CD pipeline']
# ['Gitlab']
# ['Create / Update puppet code']
# ['Observability requirements']
# ['Shotgrid']
# ['DCC applications']
# ['Shotgrid API tracking software']
# ['Mongo']
# ['REST API’s and micro-services architecture']
# ['PyQt']
# ['PySide']
# ['Data Lake and digital platform capabilities']
# ['CI/CD toolsets']
# ['AHMS']
# ['API layers']
# ['Terraform and AWS console']
# ['Timeseries']
# ['Lead data platform governance']
# ['Shells']
# ['Shell scripting basics']
# ['Development LifeCycle']
# ['SFTP servers']
# ['Microstrategy']
# ['SSH technology']
# ['VPN / VPC environments']
# ['Exceptional analysis']
# ['React Native iOS/Android mobile applications']
# ['Java.. Experience']
# ['Agile tools']
# ['Jira.. Experience']
# ['SaaS organization']
# ['Bachelor’s Degree or College Diploma']
# ['Master’s Degree and/or vendor certifications']
# ['Microsoft Certified Professional']
# ['Incumbent']
# ['Modeling']
# ['ELT']
# ['CI/CD continuous Integration']
# ['GitLab runner']
# ['Big data implementations']
# ['Apache stack']
# ['Strong Relational Data Base experience']
# ['SQL and Performance tuning']
# ['Developing Analytics']
# ['Aggregations']
# ['Unstructured Data']
# ['Python Development']
# ['Scheduler Tools']
# ['Advanced Analytics Models implementations']
# ['Strong interpersonal and communication skills']
# ['Self-starter attitude']
# ['Offshore Communications']
# ['Coordinate activities']
# ['Program SDTM']
# ['ADaM datasets']
# ['BSc']
# ['MSc']
# ['Biostatistics']
# ['SAS']
# ['Good Clinical Practice and ICH guidelines']
# ['DPDK']
# ['VPP']
# ['LANs']
# ['ARP']
# ['QAT']
# ['MITM TLS inspection']
# ['Yocto']
# ['OS fundamentals']
# ['UX designers']
# ['VLAN']
# ['BGP']
# ['IPv']
# ['Spirent']
# ['Wifi / Cellular testing experience']
# ['ESXi']
# ['Xen']
# ['Deployed VMs']
# ['Frontend']
# ['Solutions Azure Cloud']
# ['Azure Datalake']
# ['Développement Back End']
# ['Conteneurisation']
# ['Docker et Kubernetes']
# ['SCM']
# ['MsSQL']
# ['PostgresSQL']
# ['Strong JavaScript skills']
# ['Strong TypeScript skills']
# ['Strong Node.js skills']
# ['RESTful API design']
# ['Postman']
# ['NoSQL database technologies']
# ['NoSQL DBs']
# ['Bachelor’s/Master’s degree']
# ['Agile Software Development']
# ['Good technical/conceptual performance testing knowledge']
# ['Aptitude']
# ['Key Competencies/Skills   Strong programming skills']
# ['Linux/Unix Environment']
# ['Good verbal and written communication skills']
# ['Cloud testingTeradata Database Knowledge']
# ['Salesforce Developer Certified']
# ['CI/CD knowledge - Jenkins']
# ['Interoperability']
# ['Assurance']
# ['Spill']
# ['AUTOSAR components']
# ['Lauterbach']
# ['FD']
# ['Flex Ray']
# ['Fullstack Developers']
# ['API backends']
# ['UI solutions']
# ['UX strategy']
# ['Agile SCRUM team']
# ['Exhibits DevOps mindset']
# ['Documentation']
# ['User Personas']
# ['Quarterly Architecture Summits']
# ['UI Development']
# ['CSSObject Oriented Design']
# ['UI libraries']
# ['MUI']
# ['Material UI']
# ['React-query']
# ['Wretch']
# ['React-router-dom']
# ['Figma']
# ['Invision']
# ['Sigma']
# ['Storyboard']
# ['CX']
# ['User behaviors']
# ['UI performance']
# ['Agile Management Tools']
# ['VersionOne']
# ['Java development']
# ['OOP / OOAD principles']
# ['Spring/Maven/Jersey']
# ['NOSQL/Document databases']
# ['Force.com']
# ['Chip Designers']
# ['Python advanced programming skills']
# ['Jenkins pipelines']
# ['Python scripting language']
# ['Robot Framework']
# ['ServiceNow Developer Responsibilities']
# ['ServiceNow']
# ['Catalog Items']
# ['UI Policies']
# ['UI actions']
# ['ServiceNow applications']
# ['DevelopCustom workflows']
# ['ServiceNow Applications']
# ['ServiceNow Service Catalog']
# ['Configuration']
# ["ServiceNow's ITSM service catalog"]
# ['Strong analytical and problem-solving skills']
# ['Expertise level understanding']
# ['UI Actions']
# ['ServiceNow client']
# ['Scripted Web-Services']
# ['AJAX']
# ['Custom UI Changes']
# ['DOM']
# ['HTML changes']
# ['ServiceNow ITSM modules - Incident Management']
# ['Configuration Management']
# ['TCP/IP ports']
# ['IP networks']
# ['Excellent troubleshooting skills']
# ['ServiceNow platform capabilities']
# ['Orchestration']
# ['ServiceWatch']
# ['Unix Shell']
# ['ITSM']
# ['ITIL']
# ['CMDB']
# ["ServiceNow's ServiceWatch and/or Discovery tools"]
# ['Java / JEE web (UI) applications']
# ['POC']
# ['Full Stack Developer']
# ['Java/JEE']
# ['Javascript frameworks']
# ['UX tools']
# ['JAVA/JEE']
# ['SQL/PLSQL']
# ['Core Java code']
# ['Java Collections']
# ['JAVA/JEE and UI web component']
# ['Understanding basics']
# ['PL/SQL']
# ['EXTJS/Angular UI Framework']
# ['CSRs']
# ['QA team']
# ['AirFlow']
# ['Camunda']
# ['NodeJS/JavaScript']
# ['BS degree']
# ['Ruby development']
# ['Messaging concepts']
# ['Strong judgement']
# ['Basic familiarity']
# ['Amazon.com']
# ['Walmart.com']
# ['Agile development']
# ['Eagerness']
# ['Video Compression']
# ['Probability Theory']
# ['Good Python coding skills']
# ['Sophisticated knowledge']
# ['Looker']
# ['SDKs']
# ['Google APIs']
# ['Unity packages']
# ['D maths']
# ['CI / CD tools']
# ['Our tech stack']
# ['Canada’s top-performing dev team']
# ['API design reviews']
# ['Kanban Process']
# ['Amazon AWS']
# ['Relocation packages']
# ['Maya']
# ['UDK']
# ['Neo’s data platform']
# ['Neo’s engineering community']
# ['Neo']
# ['Next.JS']
# ['Refactoring']
# ['CORS']
# ['XSS']
# ['Use Spark']
# ['Databricks']
# ['BI/analytics']
# ['Apache Spark']
# ['BI/analytics tools']
# ['Winnipeg']
# ['Calgary']
# ['Illumio’s flagship network segmentation products']
# ['Mentor junior engineers']
# ['Postgres DB']
# ['Python.. Experience']
# ['Theano']
# ['M.S.']
# ['Serverless']
# ['Apollo GraphQL']
# ['Use Sentry']
# ['IaC tools']
# ['Pulumi']
# ['Python and serverless solutions']
# ['AWS Lambda']
# ['Kubernetes Jobs']
# ['Algorand, Ethereum']
# ['Hedera']
# ['Stellar']
# ['Tron']
# ['DevOps or SRE roles']
# ['Python, Shell']
# ['CI/CD platforms']
# ['Canary']
# ['Snowflake)networking routing']
# ['Agile development practices']
# ['W indows platforms']
# ['Engaging and mentoring team members']
# ['MPC']
# ['Blockchains']
# ['GDPR']
# ['SOCv']
# ['CCPA']
# ['Affinity']
# ['Java or Java-based tools']
# ['RESTful API']
# ['Troubleshoot and triage post production issues']
# ['SOAP/REST concepts']
# ['Intermediate Software Developer']
# ['SDR']
# ['The Intermediate Software Developer']
# ['Qualifications BS']
# ['Linux and Windows development environments']
# ['TCP/IP standards']
# ['Strong technical documentation']
# ['Strong organizational, tasks planning and scheduling skills']
# ['MATLAB']
# ['LabView']
# ['GUI']
# ['Cloud/Edge computing']
# ['Software Defined Radios']
# ['VITA']
# ['VRT']
# ['HiSLIP']
# ['IVI Foundation']
# ['USB driver development']
# ['Qt platform']
# ['Agile Teams']
# ['Cloud Computing']
# ['Qualifications   Degree']
# ['Enterprise Architecture roles']
# ['TOGAF']
# ['Zachman Framework']
# ['FEAF']
# ['Gartner EAP best practices']
# ['Agile methodologies']
# ['Qualifications / Skills']
# ['Scrum and backlog management tools']
# ['Affinity Earn']
# ['Transparency']
# ['Agility']
# ['Affinity Staffing']
# ['GUIs']
# ['UI/UX applications']
# ['Linux/Windows OS platforms']
# ['Web/Cloud/SaaS based solutions']
# ['PC/web/cloud based environments']
# ['Java/JavaScript']
# ['Experience interfacing test equipment']
# ['Ethernet']
# ['USB']
# ['PCIe']
# ['Strong organizational, task planning and scheduling skills']
# ['DDP.. Experience']
# ['Docker/Container.. Experience']
# ['Software-Defined Radios']
# ['SCPI']
# ['VITA- Radio Transport protocol']
# ['E-Comm, POS']
# ['Net Core/SQL']
# ['Ecommerce Platforms']
# ['Investigate/troubleshoot reported issues']
# ['Believer']
# ['Payment gateway']
# ['POS']
# ['E-comm platforms']
# ['Xamarin iOS development']
# ['Lifecycle Management Suite']
# ['The five modules']
# ['Loan Origination']
# ['Account Origination']
# ['ADO']
# ['WEB API']
# ['BootStrap']
# ['API testing and database systems concepts']
# ['Node Js   ·  Testing']
# ['Cypress']
# ['Fiddler']
# ['Azure DevOps/Visual Studio Team Services']
# ['Data Driven frameworks']
# ['Cross-browser testing']
# ['AODA testing']
# ['MongoDb']
# ['Continuous Deployment']
# ['POSTMAN']
# ['Agile frameworks']
# ['Agile Test methodologies']
# ['Product Mangers']
# ['Angular JS  · Experience']
# ['Angular/React/Vue']
# ['CSS Preprocessors']
# ['UX design prototypes']
# ['InVision']
# ['Excellent written and verbal communication']
# ['Android SDK understanding']
# ['OpenSSL']
# ['AWS infrastructure']
# ['Apache Airflow']
# ['Amazon Lambda']
# ['JavaScript framework']
# ['HTML/CSS']
# ['Object-oriented Programming Concepts']
# ['Other scripting languages']
# ['VPN infrastructure maintenance']
# ['Our escalations']
# ['Linux networking']
# ['WireGuard']
# ['Pluggable Transports']
# ['OpenVPN']
# ['IPSec']
# ['FreeRadius']
# ['Bind']
# ['Agile global technology team']
# ['DEV/QA/PO teams']
# ['SPDJI']
# ['Application & System Performance tuning']
# ['Quantitative Finance']
# ['Object Oriented Programming']
# ['I.E. Java']
# ['User Interface design']
# ['NoSql Databases']
# ['Strong Work Ethic']
# ['Thoughtfulness']
# ['Index/Benchmarks']
# ["Typically a technical Bachelor's degree"]
# ['PL/']
# ['VB.Net']
# ['Magnolia']
# ['Rest/JSON API endpoints']
# ['Git Framework']
# ['Agile Methodology']
# ['Apache Maven']
# ['Content Repository API']
# ['JCR']
# ['Symfony/Laravel/FuelPHP']
# ['MySQL and database design']
# ['LAMP Stack Unit testing']
# ['PHPUnit']
# ['SCRUM / Agile methods']
# ['GIT version control']
# ['Logical thinker']
# ['Fast learner']
# ['Self Starter']
# ['Create and present quality dashboards']
# ['KPI reporting']
# ['Tableau/Power BI']
# ['Python/R.']
# ['Your natural problem-solving skills']
# ['ISTQB']
# ['ISEB tester certificate']
# ['Growth mindset mentality']
# ['Gherkin syntax']
# ['Track quality metrics']
# ['API automation tests']
# ['Excellent debugging ability']
# ['CI/CD) tools']
# ['TeamCity']
# ['Octopus']
# ['JSON data']
# ['Bentley MX']
# ['Civils']
# ['CAD software packages']
# ['Functional and Technical Specifications']
# ['Esoteric quality control checks']
# ['QC b) Data resolution/mining c']
# ['Systems Analysts']
# ['QUALIFICATIONS']
# ['BASE SAS products']
# ['DB programming']
# ['AI based technical solutions']
# ['Optimisation']
# ['Reinforcement Learning']
# ['A Bachelor’s degree']
# ['HTML/JavaScript']
# ['Object Relational Mappers']
# ['Dapper']
# ['S.O.L.I.D. principles']
# ['Object-Relational Mappers']
# ['General cloud-computing concepts']
# ['LMS']
# ['National Instruments CVI']
# ['Debugging/fault finding']
# ['Hardware / Software integration experience']
# ['CVI']
# ['Agile Software Development - e.g. Sprint planning']
# ['Retrospective etc']
# ['Triage inbound conversations']
# ['Excellent problem-solving and analytical skills']
# ['CSE']
# ['TAM']
# ['Teilnahme']
# ['Bereich Software-Engineering']
# ['Zusammenarbeit']
# ['Group Enablers']
# ['Bewertung von IT-weit gültigen Standards']
# ['Werkzeugen']
# ['Arbeitsweisen']
# ['Technische Implementierung von Services']
# ['Schnittstellen für Cloud-native Lösungen']
# ['Selbstständige Erstellung']
# ['Entwicklung']
# ['Eigenverantwortliche Planung']
# ['Abstimmung der Architektur']
# ['Software-Lösungen']
# ['Zusammenarbeit mit Architekten']
# ['Aktive Unterstützung der Qualitätssicherung für entwickelte Software-Produkte']
# ['Implementierung']
# ['Durchführung entsprechender Tests']
# ['Integrations-Tests']
# ['Zusammenarbeit mit den verantwortlichen Quality Engineers']
# ['Team-Feedback-Prozessen (z.B. Retrospektiven']
# ['Visualisierung']
# ['Umsetzung von konkreten Optimierungsmaßnahmen']
# ['Abgeschlossenes Studium']
# ['Berufserfahrung als']
# ['Cloud Engineer oder']
# ['Ausgeprägte Kenntnisse']
# ['Mindset eines „Technologie-Vordenkers“ wünschenswert']
# ['Erfahrungen']
# ['DevOps-Tools']
# ['Methoden']
# ['Mit-']
# ['Prinzipien']
# ['Bereich Cloud Engineering']
# ['Betrieb von Plattformen']
# ['AWS-Umfeld']
# ['IT-Service Management Modell']
# ['Teamplayer']
# ['Fließend Englischkenntnisse']
# ['Multi-Domain Operations (MDO) warfighting capabilities']
# ['DoD']
# ['Computer simulation']
# ['Certs']
# ['TS/SCI']
# ['Agile teams']
# ['RDBMS, Microservices']
# ['REST-based APIs']
# ['RDBMS database concepts']
# ['Azure Education']
# ['Pulse Secure VPN Linux/Windows clients']
# ['Review user documentation']
# ['BS/BE/B-Tech']
# ['Linux/MacOS/Windows platforms']
# ['EAP']
# ['Active Directory/LDAP']
# ['Radius']
# ['Windows specific libraries']
# ['IPC']
# ...
# ['Client’s existing applications']
# ['Yieldmo ecosystem']
# ['Client’s growing teams']
# ['SSPs']
# ['DMPs']
# ['Analytical']
# ['Debugging Skills']
# ['ASP.Net core']
# ['Webforms']
# ['C#, OOPS Concept']
# ['B.Tech']
# ['Mac/iOS application development']
# ['Objective C/Swift (preferably Enterprise apps']
# ['Mac/iOS frameworks']
# ['CFNetwork']
# ['Apple’s recommended design principles']
# ['Multi-threaded programming']
# ['JSON/ XML']
# ['Agile development methodology']
# ['Agile Framework']
# ['Agile or Scrum software development methodologies Ability']
# ['WCAG requirements']
# ['MicroStrategy Web']
# ['Dashboard']
# ['Visual Insights']
# ['Strong technical server administration & performance tuning skills']
# ['Reports rationalization']
# ['Programming language Dart']
# ['Native Programming languages']
# ['Swift/Objective-C. knowledge']
# ['Dart SDK']
# ['Bloc coding structure']
# ['Networking libraries']
# ['Local storage libraries']
# ['Crashlytics']
# ['Mapbox']
# ['Dart/Flutter coding standard']
# ['Mentoring others']
# ['Laravel Framework/ CodeIgniter Minimum experience']
# ['Laravel/CodeIgniter development']
# ['MVC design patterns']
# ['Years Required Educational Qualification']
# ['Spring Microservices']
# ['RDMS']
# ['Java Design patterns']
# ['RESTful Web services']
# ['Power Mock']
# ['Liquibase']
# ['IntelliJ Idea']
# ['Java technologies']
# ['Javascript based frameworks']
# ['Calypso Technology']
# ['Cloud Technology / AWS']
# ['API Gateway EC']
# ['CDN']
# ['Auto Scaling']
# ['Elastic Beanstalk']
# ['JScript']
# ['Strong documentation']
# ['Scripts']
# ['Troubleshooting interface software']
# ['C++ / any OOPs language software development experience']
# ['OS and Data structure fundamentals']
# ['SQL knowledge']
# ['BI tools']
# ['Microsoft Power BI']
# ['Lumira']
# ['Java memory']
# ['Code backend services']
# ['No-SQL/ MongoDB']
# ['SQL based data bases']
# ['PortgresSQL']
# ['Angular / React UI Development']
# ['Iteratively']
# ['CSS Exposure']
# ['AWS/Azure']
# ['Toplyne']
# ['Kafka OR Elastic search']
# ['Unix/Linux operating systems']
# ['Qualifications / Skillsets']
# ['OpenStack']
# ['CloudFoundry']
# ['ETFs']
# ['Factset']
# ['Reuters']
# ['BSc degree']
# ['A Constant self-learner']
# ['Flair']
# ['Lateral thinking']
# ['SDLC  • Experience']
# ['Healthcare Analytics domain']
# ['Microsoft Azure SQL Database']
# ['Azure Cosmos Database']
# ['Azure Data Factory Service']
# ['SSAS cubes']
# ['MDX queries']
# ['Tabular Model  • Experience']
# ['Process Diagrams']
# ['Block Diagrams  • Good Communication and Collaboration skills  • Ability']
# ['Software Configuration Management tools']
# ['SQL Server development']
# ['ETL/DB and QA team']
# ['ETL packages']
# ['Frontend CSS frameworks']
# ['DB architecture design and programming templates']
# ['API Creation']
# ['GIT - Basic knowledge AWS services']
# ['TypeScript knowledge']
# ['Immediate joiners']
# ['Excellent programmer']
# ['Excellent code designing skills']
# ['SQL Agent Jobs']
# ['ASP.NET MVC Framework']
# ['Git/VSTS']
# ['DevOps and production environments']
# ['BASH']
# ['Snort']
# ['Squid']
# ['Vyatta']
# ['IP tables']
# ['UFW']
# ['My SQL']
# ['Query design']
# ['Stored Procedures']
# ['Data modelling']
# ['Data validation checks']
# ['Automotive embedded software development experience']
# ['RTOS/Non RTOS platform • Experience']
# ['AUTOSAR']
# ['CAN gateway module']
# ['UDS diagnostic']
# ['MCAL Configuration']
# ['EB/Vector']
# ['Autosar']
# ['AWS IaaS Administration']
# ['Python / Go / Ruby / Javascript']
# ['Managing cloud based infrastructure']
# ['Python, Go, Ruby, JavaScript, Shell/Bash Scripting, Java, HTML & CSS experience']
# ['Web frameworks']
# ['Code repository best practices']
# ['Git Flow']
# ['Continuous Integration tools']
# ['Jenkins/Hudson']
# ['Harness']
# ['Ant']
# ['Cloud Micro']
# ['AI/ML/Analytics']
# ['DevOps and Tech support teams']
# ['UX team']
# ['Bachelor/Master’s degree']
# ['Ext JS']
# ['BackboneJS']
# ['Template libraries']
# ['TDD methodologies']
# ['Strong programming and debugging skills']
# ['Flutter knowledge']
# ['Maropost']
# ['IP address']
# ['Subnet Mask']
# ['Static Route']
# ['DHCP Server']
# ['Setup Printers']
# ['Scanners']
# ["Bachelor's degree/Master degree"]
# ['LAN / WAN']
# ['MacOS/Unix']
# ['Shell Scripting Languages']
# ['HubSpot']
# ['Gainsight']
# ['Bachelors/ Masters']
# ['Java/Swift experience']
# ['Android Keyboard API']
# ['Min - yrs']
# ['Active Directory Administration']
# ['DNS, DHCP, GPO, ADCS']
# ['SQL Server Administration']
# ['Co-located Datacenter Design']
# ['IPv – AD and Server Environments']
# ['Structured and unstructured data backup']
# ['Okta Administration']
# ['Intune/SCCM Administration']
# ['MacOS knowledge']
# ['NoSQL data storage systems']
# ['Prototype product components']
# ['AJAX components']
# ['TTD']
# ['Highly proactive, result-oriented and team player']
# ['Solr']
# ['Application/Web Servers']
# ['Strong understanding/expertise']
# ['APIs/ Micro services architecture']
# ['Data modelling and database design experience']
# ['Mongo/Dynamo Helpful']
# ['GIT Hub']
# ['SW development processes']
# ['Object Oriented design']
# ['KPI']
# ['Design layouts']
# ['Developed complex calculated measures']
# ['DAX']
# ['BI Viz solutions']
# ['Bachelor’s/master’s degree']
# ['HANA']
# ['Tableau/Qlik']
# ['Lead troubleshooting']
# ['Technically relevant field issues']
# ['ASP']
# ['REST/WebAPI']
# ['Azure Kubernetes Service']
# ['Messaging']
# ['Microsoft technology stacks']
# ['Enterprise Integration']
# ['OpenIDConnect']
# ['WS-Security']
# ['MSSQL server /RDBMS, experience']
# ['Ubuntu']
# ['Ubuntu rates']
# ['JVM-based innovation']
# ['Debug issues']
# ['Strong Technical expertise']
# ['Designing & Developing Applications']
# ['Full lifecycle development']
# ['Knowledge/Willingness']
# ['Allscripts']
# ['Java/Java EE application development']
# ['RDBMS DB']
# ['Multithreaded applications']
# ['Jira tool']
# ['Agile Methodologies']
# ['CentOS']
# ['Fedora']
# ['Rhel']
# ['JavaScript/HTML/CSS']
# ['Jenkins.. Knowledge']
# ['NoSql database']
# ['MongoDB / Cassandra.. Knowledge']
# ['Angular JS/']
# ['Linux Software Integration']
# ['Config Management']
# ['Continuous integration / continuous deployment CI/CD tools']
# ['SCM tools']
# ['SDK linux platform distributions']
# ['Linux integration and release strategy']
# ['Linux/Ubuntu/Fedora software integration']
# ['Hands-on familiarity']
# ['Linux distributions']
# ['OpenEmbedded-Core Project']
# ['OE-Core']
# ['OE-dev']
# ['Yocto Project']
# ['Linux-based systems']
# ['OpenSource']
# ['Good fundamentals']
# ['Atlassian tools Jira']
# ['Confluence, git stash']
# ['GNU/']
# ['Linux Development Tools']
# ['Bitbake']
# ['CruiseControl']
# ['Lint']
# ['Beneficial: basic Automotive SPICE knowledge']
# ['Beneficial: background']
# ['Strong Java/Kotlin development experience']
# ['Architectural patterns']
# ['Strong interpersonal communication']
# ['Java & KotlinExtensive experience']
# ['AndroidTV']
# ['FireTV']
# ['Chromecast']
# ['VR/AR']
# ['Obj-C/Swift']
# ['Agile, Continuous Integration/Distribution']
# ['Test Driven DevelopmentMust']
# ['DRM']
# ['OVPs']
# ['B.E / B. Tech']
# ['Android - Kotlin']
# ['Jetpack libraries']
# ['Android recommended user interfaces']
# ['Preferred qualifications']
# ['Barracuda engineers']
# ['Barracuda appliances']
# ['Linux based distributions']
# ['Strong communication and interpersonal skills']
# ['ASP.Net MVC']
# ['Entity framework']
# ['RDBMS especiallySQL Server']
# ['CSS and Material UI']
# ['Knowledge inGraph QL']
# ['Experience withDocker']
# ['Skills And Qualifications\xa0 Strong proficiency']
# ['Nest.js']
# ['Elastic Container Service']
# ['SAS programming language']
# ['Critical thinking and excellent verbal and written communication skills']
# ['Problem-solving and analytical abilities']
# ['SAS Enterprise Guide']
# ['Your Key Attributes  Strong data analysis']
# ['Exceptional communication and presentation skills']
# ['Charismatic personality']
# ['Micronaut/Kotlin']
# ['DevOps Support']
# ['Networking concepts']
# ['VPN tunnels']
# ['SQL · Ability']
# ['Container Platform / Kubernetes technologies']
# ['CI/CD best practices']
# ['SCOM']
# ['VMWare vCenter']
# ['VMWare Horizon']
# ['Citrix Virtual App']
# ['Virtual Desktop']
# ['Java application design']
# ['JEE/Java']
# ['GraphDB']
# ['Test Automation Development']
# ['Microfocus ALM']
# ['Microfocus Octane']
# ['Microfocus Load Runner']
# ['Katalon']
# ['Microfocus Loadrunner']
# ['Bootstrap Angular']
# ['Full Stack Java/JEE software design and development experience']
# ['Algorithm Design']
# ['AWS Glue']
# ['AWS Lake FormationAzure']
# ['Data FactoryGCP']
# ['DataFlow']
# ['GCS']
# ['Big Data Stacks']
# ['Spark Streaming']
# ['Strong experience building data ingestion pipelines']
# ['Load workload']
# ['MQ technologies']
# ['B.S. Computer Science']
# ['Solid oral, written, presentation, collaboration and interpersonal communication skills']
# ['Salesforce Certifications']
# ['Angular, React, Vue) and related technologies']
# ['JS - features']
# ['Smartwatch']
# ['Node.jsExperience']
# ['MS SQL ServerSDLC']
# ['Good modeling']
# ['SOLR']
# ['Adobe AEM']
# ['Product Cockpit']
# ['WCMS']
# ['EhCache']
# ['Oracle CoherenceVarious']
# ['Bazaarvoice']
# ['Hybris Web Commerce platforms']
# ['Excellent problem- solving skills']
# ['Hadoop, NoSQL']
# ['Data-oriented personality']
# ['PI']
# ['IoT Data Platform architectures']
# ['Containers and Resource Management systems']
# ['English proficiency']
# ['Java/ Scala']
# ['BashBig Data stack']
# ['ZookeperNoSQL']
# ['Cassandra/ Hbase']
# ['Kafka Streams']
# ['IOT Hub']
# ['Storage Queues']
# ['Stream AnalyticsData Visualization']
# ['QlikViewETL']
# ['Streaming Pipelines']
# ['Apache Oozie']
# ['NiFi']
# ['StreamsetsOperation']
# ['Cluster operation']
# ['Cluster planningSearch']
# ['Elasticsearch/ELKInMemory']
# ['Ignite']
# ['RedisSolid Cloud experience']
# ['Cubes']
# ['Visualization']
# ['SageMaker']
# ['Tensorflow)Enterprise Design Patterns']
# ['Component/ Integration Testing']
# ['SQL optimizationExperience']
# ['ZeroMQ/ RabbitMQRest']
# ['SOAPBuild Systems']
# ['SBT']
# ['GradleDocker']
# ['Proficiency and enterprise work experience']
# ['Angular (Angular +']
# ['Data Technology Consultants']
# ['Any object-oriented/object function scripting language']
# ['Azure: Storage']
# ['ReduxAngularJSRxJSVirtual']
# ['Real DOMsMVC']
# ['Design & Develop web backend solutions']
# ['Strong database fundamentals']
# ['ReduxKnowledge']
# ['MVP patternsCore JavaScriptCSS, HTML']
# ['Adaptive']
# ['JS, Java']
# ['Core JavaCreational']
# ['Web DesignRESTful']
# ['APICI']
# ['Automation Framework']
# ['Defects documentation']
# ['REST & SOAP API testing']
# ['SOAPUI']
# ['Groovy Scripting']
# ['Excellent organizational, troubleshooting and analytical skills']
# ['Scope and estimate project tasks']
# ['Flask/Django']
# ['Strong SQL knowledge']
# ['AWS\\']
# ['An acquaintance']
# ['Strong Linux knowledge']
# ['GPFS']
# ['Configuration management']
# ['Ganglia']
# ['NFS/SAMBA/GPFS/Lustre']
# ['Provisioning']
# ['Foreman']
# ['RedHat Satellite']
# ['Strong Troubleshooting']
# ['FinTech']
# ['Enablement']
# ['Spring Batch']
# ['SQLNice']
# ['JMS/MQ']
# ['Splunk/Dynatrace']
# ['CSSExperience']
# ['Mainframe/Backend Systems - Knowledge']
# ['SmartBear']
# ['Reporting - Jira']
# ['Mainframe Automation']
# ['Serenity']
# ['Excellent communication and documentation skillsEnglish']
# ['Smart Contract security audits']
# ['NFT related protocols']
# ['ERC-']
# ['ERC']
# ['Solidity contracts']
# ['L networks']
# ['Polygon']
# ['Slither']
# ['Echidna']
# ['Mythril']
# ['HW bring-up']
# ['ARM Cortex M/A']
# ['LINUX']
# ['IIC']
# ['FPGA development']
# ['ASIC development flow']
# ['RTL']
# ['SIMD processors']
# ['GPUs']
# ['FPGAs']
# ['Amgen']
# ['DevOps frameworks']
# ['Informatics solutions']
# ['High School / GED']
# ['High learning agility']
# ['Office  Power Platform environment tools']
# ['SQL reporting']
# ['Hands-on hour series']
# ['PPAP documentation']
# ['APQP']
# ['FMEA']
# ['NCE-Prototype']
# ['D methodology']
# ['Lead PFMEA']
# ['Zero Defect program']
# ['Electrical or Mechanical Engineering Degree']
# ['PFMEA']
# ['Strong analytical and communication skills']
# ['TD']
# ['Monitor system life cycles']
# ['RFI/RFP']
# ['SLAs']
# ['Undergraduate Degree']
# ['Adeptness']
# ['Strong subject matter expertise']
# ['Readiness']
# ['TD services']
# ['Skillsets Required']
# ['Now related configurations']
# ['SQL/NoSQL database']
# ['G RAN']
# ['OAM']
# ['OEM solutions']
# ['G networks']
# ['SCTP']
# ['Precision Timing Protocol']
# ['PTP']
# ['Fronthaul']
# ['Midhaul']
# ['Backhaul']
# ['G/G SW development experience']
# ['Carrier grade Transport solution']
# ['Organized, goal-oriented, self-starter']
# ['Demonstrable C/C++ programming experience']
# ['AWS IoT']
# ['RDS, S']
# ['EKS/ECS']
# ['Python frameworks']
# ['Python Data Science Libraries']
# ['Data Analysis/Data Cleaning/Feature Engineering/Modelling/Testing/Validation']
# ['Sagemaker/Step Function/ECS/Lambdas']
# ['RTOS environments']
# ['Board Software Packages']
# ['BSPs']
# ['SPI and Ethernet protocols']
# ['OpenVG']
# ['Champion core DevOps behaviors']
# ['Azure Certifications AZ-']
# ['AZ-']
# ['NodeJs applications']
# ['Octopus Deploy']
# ['GitHub Enterprise']
# ['Swift/Objective-C.']
# ['OOP, SOLID, Design Patterns']
# ['Experience consuming web services']
# ['Azure environments']
# ['Geography']
# ['ArcMap']
# ["Sonder's reporting dashboards"]
# ['Sonder’s business']
# ['Sonder’s business KPIs']
# ['Expert Python coding skills']
# ['Expert SQL and data modeling skills']
# ['ETL jobs']
# ['Commercial and Leadership/Mentorship exposure']
# ['Fullstack development']
# ['Strong Frontend background']
# ['React/Redux']
# ['Strong Backend background']
# ['Research new cloud and software technologies']
# ['Complete self-paced and online professional training']
# ['Current AWS certifications']
# ['RideFlag applications']
# ['VIPER design pattern']
# ['DDP']
# ['Docker/Container']
# ['MOBIA clients']
# ['MOBIA']
# ['Red Hat OpenShift']
# ['Red Hat OpenStack']
# ['Google Anthos']
# ['PaaS solutions']
# ['HashiCorp stack']
# ['Bilingual (French/English) language']
# ['USB interface']
# ['IVI']
# ['Self-starter/motivator']
# ['Outstanding work ethic']
# ['Computer Networking']
# ['Public Cloud Stacks']
# ['MSAZ']
# ['Public Cloud Networking']
# ['Wireline']
# ['CDN technologies']
# ['BGP, ISIS']
# ['Segment Routing']
# ['EVPN']
# ['Bilingual - French/English']
# ['CI/CD tooling']
# ['ARM Templates']
# ['GCP Templates']
# ['Workplace culture enthusiast']
# ['Infrastructure and Cybersecurity teams']
# ['O environment']
# ['OneDrive']
# ['OS deployment configuration']
# ['WIM files']
# ['Driver Packages']
# ['Customized Task Sequences']
# ['UEFI/BIOS']
# ['Registry Configuration']
# ['Azure Virtual Desktop..  Design']
# ['Video Conferencing systems']
# ['Bayshore EA standards']
# ['XDR technologies']
# ['ATP']
# ['Windows  OS and associated services']
# ['AAD']
# ['Azure MFA']
# ['SSO Apps']
# ['AAD connect']
# ['M tenant/applications']
# ['ProPlus']
# ['Enterprise Mobility']
# ['Smartphones']
# ['O solution design']
# ['DMZ architecture']
# ['Security and Privacy Frameworks']
# ['PIPEDA']
# ['PHIPA']
# ['SOC']
# ['Microsoft Graph']
# ['IaaC']
# ['Ansible/Terraform']
# ['Microsoft O']
# ['Modern Desktop Administrator Associate']
# ['Identity Fundamentals']
# ['Logitech']
# ['Poly..  Design']
# ['Azure Virtual Desktop']
# ['Java/JavaScript/Groovy/Python']
# ['IntelliJ/Eclipse/Visual Code/WebStorm..  Experience']
# ['MacOS X']
# ['Cypher query language']
# ['Java RESTful APIs']
# ['Strong UI development']
# ['JS Framework']
# ['RESTful Java APIs']
# ['Microservices Architecture']
# ['Strong SQL coding skills']
# ['Strong problem-solving skills']
# ['C#, ASP.NET framework']
# ['DotNet Core']
# ['MVC/Razor page']
# ['Net WebAPI']
# ['HTML/SASS/CSS']
# ['MS SQL database development']
# ['Strong design and coding skills']
# ['QA teams']
# ['QA time']
# ['J avaScript']
# ['J SON et PowerShell']
# ['PowerBI or data visualization tools']
# ['Full lifecycle application development']
# ['Angular, Java']
# ['HL FHIR']
# ['SPA application development']
# ['Angular, Bootstrap']
# ['HTML/CSS/JS, ES']
# ['OpenID Connect']
# ['RedHat OpenShift']
# ['HL']
# ["A completed Bachelor's degree"]
# ['Actuarial Science']
# ['ICAAP models']
# ['IFRS']
# ['Basel II']
# ['SAS Base']
# ['SAS EG']
# ['LCHH format/model']
# ['HTML/CSS/PhP']
# ['QA specialists']
# ['Accomplishments']
# ['Microsoft Azure cloud development experience']
# ['Perks']
# ['MVP releases']
# ['MM interfaces']
# ['NoSQL/KV Stores']
# ['Messaging Queuing Services']
# ['GitHub use']
# ['Results-oriented, data-driven, experimental attitude']
# ['Boundless positivity']
# ['Strong troubleshooting and problem-solving skills']
# ['Statflo']
# ['Roku applications development']
# ['Roku applications']
# ['Brightscript Scenegraph']
# ['Swift/Objective-C']
# ['Server-side scripting skills']
# ['Bitbucket / Git']
# ['Agile, Continuous Integration']
# ['CMIS']
# ['C / embedded software']
# ['Leadership qualities']
# ['Actalent']
# ['Self-motivated, enthusiastic and strong drive']

# %%
kl
# Out:
# ['[',
#  "'",
#  'J',
#  'a',
#  'v',
#  'a',
#  ' ',
#  'S',
#  't',
#  'r',
#  'e',
#  'a',
#  'm',
#  's',
#  "'",
#  ']',
#  '[',
#  "'",
#  'O',
#  'b',
#  'j',
#  'e',
#  'c',
#  't',
#  ' ',
#  'O',
#  'r',
#  'i',
#  'e',
#  'n',
#  't',
#  'e',
#  'd',
#  ' ',
#  'a',
#  'n',
#  'a',
#  'l',
#  'y',
#  's',
#  'i',
#  's',
#  "'",
#  ']',
#  '[',
#  "'",
#  'R',
#  'e',
#  'l',
#  'a',
#  't',
#  'i',
#  'o',
#  'n',
#  'a',
#  'l',
#  ' ',
#  'D',
#  'a',
#  't',
#  'a',
#  'b',
#  'a',
#  's',
#  'e',
#  's',
#  "'",
#  ']',
#  '[',
#  "'",
#  'S',
#  'Q',
#  'L',
#  "'",
#  ']',
#  '[',
#  "'",
#  'O',
#  'R',
#  'M',
#  "'",
#  ']',
#  '[',
#  "'",
#  'J',
#  'P',
#  'A',
#  "'",
#  ']',
#  '[',
#  "'",
#  'H',
#  'i',
#  'b',
#  'e',
#  'r',
#  'n',
#  'a',
#  't',
#  'e',
#  "'",
#  ']',
#  '[',
#  "'",
#  'M',
#  'y',
#  'B',
#  'a',
#  't',
#  'i',
#  's',
#  "'",
#  ']',
#  '[',
#  "'",
#  'G',
#  'i',
#  't',
#  '.',
#  '.',
#  ' ',
#  'F',
#  'a',
#  'm',
#  'i',
#  'l',
#  'i',
#  'a',
#  'r',
#  'i',
#  't',
#  'y',
#  "'",
#  ']',
#  '[',
#  "'",
#  'M',
#  'a',
#  'v',
#  'e',
#  'n',
#  "'",
#  ']',
#  '[',
#  "'",
#  'G',
#  'r',
#  'a',
#  'd',
#  'l',
#  'e',
#  '.',
#  '.',
#  ' ',
#  'F',
#  'a',
#  'm',
#  'i',
#  'l',
#  'i',
#  'a',
#  'r',
#  'i',
#  't',
#  'y',
#  "'",
#  ']',
#  '[',
#  "'",
#  'F',
#  'a',
#  'm',
#  'i',
#  'l',
#  'i',
#  'a',
#  'r',
#  'i',
#  't',
#  'y',
#  "'",
#  ']',
#  '[',
#  "'",
#  'D',
#  'e',
#  'm',
#  'o',
#  'n',
#  's',
#  't',
#  'r',
#  'a',
#  'b',
#  'l',
#  'e',
#  ' ',
#  'e',
#  'x',
#  'p',
#  'e',
#  'r',
#  'i',
#  'e',
#  'n',
#  'c',
#  'e',
#  "'",
#  ']',
#  '[',
#  "'",
#  'B',
#  'a',
#  'c',
#  'h',
#  'e',
#  'l',
#  'o',
#  'r',
#  ' ',
#  'o',
#  'r',
#  ' ',
#  'M',
#  'a',
#  's',
#  't',
#  'e',
#  'r',
#  ' ',
#  'd',
#  'e',
#  'g',
#  'r',
#  'e',
#  'e',
#  "'",
#  ']',
#  '[',
#  "'",
#  'S',
#  'T',
#  'E',
#  'M',
#  ' ',
#  'm',
#  'a',
#  'j',
#  'o',
#  'r',
#  's',
#  "'",
#  ']',
#  '[',
#  "'",
#  'S',
#  't',
#  'r',
#  'o',
#  'n',
#  'g',
#  ' ',
#  'a',
#  'l',
#  'g',
#  'o',
#  'r',
#  'i',
#  't',
#  'h',
#  'm',
#  's',
#  "'",
#  ']',
#  '[',
#  "'",
#  'P',
#  'y',
#  't',
#  'h',
#  'o',
#  'n',
#  "'",
#  ']',
#  '[',
#  "'",
#  'S',
#  'c',
#  'a',
#  'l',
#  'a',
#  ' ',
#  'p',
#  'r',
#  'o',
#  'g',
#  'r',
#  'a',
#  'm',
#  'm',
#  'i',
#  'n',
#  'g',
#  ' ',
#  'e',
#  'x',
#  'p',
#  'e',
#  'r',
#  'i',
#  'e',
#  'n',
#  'c',
#  'e',
#  "'",
#  ']',
#  '[',
#  "'",
#  'E',
#  'x',
#  'c',
#  'e',
#  'p',
#  't',
#  'i',
#  'o',
#  'n',
#  'a',
#  'l',
#  ' ',
#  'p',
#  'r',
#  'o',
#  'f',
#  'i',
#  'c',
#  'i',
#  'e',
#  'n',
#  'c',
#  'y',
#  "'",
#  ']',
#  '[',
#  "'",
#  'M',
#  'y',
#  'S',
#  'Q',
#  'L',
#  "'",
#  ']',
#  '[',
#  "'",
#  'O',
#  'r',
#  'a',
#  'c',
#  'l',
#  'e',
#  "'",
#  ']',
#  '[',
#  "'",
#  'N',
#  'o',
#  'S',
#  'Q',
#  'L',
#  ' ',
#  'S',
#  't',
#  'o',
#  'r',
#  'e',
#  's',
#  "'",
#  ']',
#  '[',
#  "'",
#  'C',
#  'l',
#  'i',
#  'c',
#  'k',
#  'h',
#  'o',
#  'u',
#  's',
#  'e',
#  "'",
#  ']',
#  '[',
#  "'",
#  'D',
#  'i',
#  's',
#  't',
#  'r',
#  'i',
#  'b',
#  'u',
#  't',
#  'e',
#  'd',
#  ' ',
#  'P',
#  'r',
#  'o',
#  'c',
#  'e',
#  's',
#  's',
#  'i',
#  'n',
#  'g',
#  ' ',
#  'E',
#  'n',
#  'g',
#  'i',
#  'n',
#  'e',
#  's',
#  "'",
#  ']',
#  '[',
#  "'",
#  'A',
#  'p',
#  'a',
#  'c',
#  'h',
#  'e',
#  ' ',
#  'F',
#  'l',
#  'i',
#  'n',
#  'k',
#  "'",
#  ']',
#  '[',
#  "'",
#  'C',
#  'e',
#  'l',
#  'e',
#  'r',
#  'y',
#  "'",
#  ']',
#  '[',
#  "'",
#  'D',
#  'i',
#  's',
#  't',
#  'r',
#  'i',
#  'b',
#  'u',
#  't',
#  'e',
#  'd',
#  ' ',
#  'Q',
#  'u',
#  'e',
#  'u',
#  'e',
#  's',
#  "'",
#  ']',
#  '[',
#  "'",
#  'A',
#  'W',
#  'S',
#  ' ',
#  'K',
#  'i',
#  'n',
#  'e',
#  's',
#  'i',
#  's',
#  "'",
#  ']',
#  '[',
#  "'",
#  'G',
#  'C',
#  'P',
#  ' ',
#  'P',
#  'u',
#  's',
#  'S',
#  'u',
#  'b',
#  "'",
#  ']',
#  '[',
#  "'",
#  'G',
#  'C',
#  'P',
#  "'",
#  ']',
#  '[',
#  "'",
#  'A',
#  'z',
#  'u',
#  'r',
#  'e',
#  "'",
#  ']',
#  '[',
#  "'",
#  'A',
#  'W',
#  'S',
#  "'",
#  ']',
#  '[',
#  "'",
#  'E',
#  'x',
#  'c',
#  'e',
#  'l',
#  'l',
#  'e',
#  'n',
#  't',
#  ' ',
#  'U',
#  'n',
#  'i',
#  'x',
#  '/',
#  'L',
#  'i',
#  'n',
#  'u',
#  'x',
#  ' ',
#  'e',
#  'x',
#  'p',
#  'e',
#  'r',
#  'i',
#  'e',
#  'n',
#  'c',
#  'e',
#  ' ',
#  'a',
#  'n',
#  'd',
#  ' ',
#  'p',
#  'r',
#  'o',
#  'g',
#  'r',
#  'a',
#  'm',
#  'm',
#  'i',
#  'n',
#  'g',
#  ' ',
#  'e',
#  'x',
#  'p',
#  'e',
#  'r',
#  'i',
#  'e',
#  'n',
#  'c',
#  'e',
#  "'",
#  ']',
#  '[',
#  "'",
#  'I',
#  'P',
#  'C',
#  ' ',
#  'm',
#  'e',
#  'c',
#  'h',
#  'a',
#  'n',
#  'i',
#  's',
#  'm',
#  's',
#  "'",
#  ']',
#  '[',
#  "'",
#  'T',
#  'C',
#  'P',
#  '/',
#  'I',
#  'P',
#  "'",
#  ']',
#  '[',
#  "'",
#  'K',
#  'a',
#  'f',
#  'k',
#  'a',
#  "'",
#  ']',
#  '[',
#  "'",
#  'A',
#  'P',
#  'I',
#  ' ',
#  'g',
#  'a',
#  't',
#  'e',
#  'w',
#  'a',
#  'y',
#  's',
#  "'",
#  ']',
#  '[',
#  "'",
#  'C',
#  'A',
#  'P',
#  ' ',
#  'T',
#  'h',
#  'e',
#  'o',
#  'r',
#  'e',
#  'm',
#  "'",
#  ']',
#  '[',
#  "'",
#  'R',
#  'A',
#  'F',
#  'T',
#  "'",
#  ']',
#  '[',
#  "'",
#  'P',
#  'a',
#  'x',
#  'o',
#  's',
#  "'",
#  ']',
#  '[',
#  "'",
#  'C',
#  'I',
#  '/',
#  'C',
#  'D',
#  "'",
#  ']',
#  '[',
#  "'",
#  'G',
#  'i',
#  't',
#  'h',
#  'u',
#  'b',
#  "'",
#  ']',
#  '[',
#  "'",
#  'M',
#  'a',
#  'k',
#  'e',
#  'f',
#  'i',
#  'l',
#  'e',
#  's',
#  "'",
#  ']',
#  '[',
#  "'",
#  'M',
#  'i',
#  'c',
#  'r',
#  'o',
#  's',
#  'e',
#  'r',
#  'v',
#  'i',
#  'c',
#  'e',
#  's',
#  "'",
#  ']',
#  '[',
#  "'",
#  'G',
#  'C',
#  'P',
#  'N',
#  'o',
#  'd',
#  'e',
#  '.',
#  'j',
#  's',
#  "'",
#  ']',
#  '[',
#  "'",
#  'R',
#  'E',
#  'S',
#  'T',
#  ' ',
#  'A',
#  'P',
#  'I',
#  's',
#  ' ',
#  's',
#  'e',
#  'r',
#  'v',
#  'i',
#  'c',
#  'e',
#  's',
#  'E',
#  'x',
#  'p',
#  'e',
#  'r',
#  'i',
#  'e',
#  'n',
#  'c',
#  'e',
#  ' ',
#  'w',
#  'r',
#  'i',
#  't',
#  'i',
#  'n',
#  'g',
#  ' ',
#  't',
#  'o',
#  'o',
#  'l',
#  's',
#  "'",
#  ']',
#  '[',
#  "'",
#  'R',
#  'u',
#  'b',
#  'y',
#  "'",
#  ']',
#  '[',
#  "'",
#  'P',
#  'e',
#  'r',
#  'l',
#  'E',
#  'x',
#  'p',
#  'e',
#  'r',
#  'i',
#  'e',
#  'n',
#  'c',
#  'e',
#  "'",
#  ']',
#  '[',
#  "'",
#  'B',
#  'a',
#  'z',
#  'e',
#  'l',
#  "'",
#  ']',
#  '[',
#  "'",
#  'H',
#  'T',
#  'T',
#  'P',
#  ' ',
#  '/',
#  'w',
#  'e',
#  'b',
#  's',
#  'o',
#  'c',
#  'k',
#  'e',
#  't',
#  "'",
#  ']',
#  '[',
#  "'",
#  'R',
#  'e',
#  'd',
#  'i',
#  's',
#  "'",
#  ']',
#  '[',
#  "'",
#  'W',
#  'e',
#  'b',
#  ' ',
#  'U',
#  'I',
#  'E',
#  'x',
#  'p',
#  'e',
#  'r',
#  'i',
#  'e',
#  'n',
#  'c',
#  'e',
#  "'",
#  ']',
#  '[',
#  "'",
#  'J',
#  'a',
#  'v',
#  'a',
#  'S',
#  'c',
#  'r',
#  'i',
#  'p',
#  't',
#  "'",
#  ']',
#  '[',
#  "'",
#  'H',
#  'T',
#  'M',
#  'L',
#  "'",
#  ']',
#  '[',
#  "'",
#  'C',
#  'S',
#  'S',
#  "'",
#  ']',
#  '[',
#  "'",
#  'A',
#  'n',
#  'g',
#  'u',
#  'l',
#  'a',
#  'r',
#  "'",
#  ']',
#  '[',
#  "'",
#  'M',
#  'e',
#  't',
#  'e',
#  'o',
#  'r',
#  "'",
#  ']',
#  '[',
#  "'",
#  'E',
#  'm',
#  'b',
#  'e',
#  'r',
#  "'",
#  ']',
#  '[',
#  "'",
#  'K',
#  'n',
#  'o',
#  'c',
#  'k',
#  'o',
#  'u',
#  't',
#  "'",
#  ']',
#  '[',
#  "'",
#  'U',
#  'I',
#  ' ',
#  'C',
#  'o',
#  'm',
#  'p',
#  'o',
#  'n',
#  'e',
#  'n',
#  't',
#  ' ',
#  'l',
#  'i',
#  'b',
#  'r',
#  'a',
#  'r',
#  'i',
#  'e',
#  's',
#  "'",
#  ']',
#  '[',
#  "'",
#  'V',
#  'u',
#  'e',
#  "'",
#  ']',
#  '[',
#  "'",
#  'B',
#  'o',
#  'o',
#  't',
#  's',
#  't',
#  'r',
#  'a',
#  'p',
#  "'",
#  ']',
#  '[',
#  "'",
#  'E',
#  'S',
#  "'",
#  ']',
#  '[',
#  "'",
#  'T',
#  'y',
#  'p',
#  'e',
#  'S',
#  'c',
#  'r',
#  'i',
#  'p',
#  't',
#  ...]

# %%
df = pd.DataFrame(az,columns = ['RAW DATA'])

# %%
df
# Out:
#                                                RAW DATA
# 0                                      ['Java Streams']
# 1                          ['Object Oriented analysis']
# 2                              ['Relational Databases']
# 3                                               ['SQL']
# 4                                               ['ORM']
# 5                                               ['JPA']
# 6                                         ['Hibernate']
# 7                                           ['MyBatis']
# 8                                 ['Git.. Familiarity']
# 9                                             ['Maven']
# 10                             ['Gradle.. Familiarity']
# 11                                      ['Familiarity']
# 12                          ['Demonstrable experience']
# 13                        ['Bachelor or Master degree']
# 14                                      ['STEM majors']
# 15                                ['Strong algorithms']
# 16                                           ['Python']
# 17                     ['Scala programming experience']
# 18                          ['Exceptional proficiency']
# 19                                            ['MySQL']
# 20                                           ['Oracle']
# 21                                     ['NoSQL Stores']
# 22                                       ['Clickhouse']
# 23                   ['Distributed Processing Engines']
# 24                                     ['Apache Flink']
# 25                                           ['Celery']
# 26                               ['Distributed Queues']
# 27                                      ['AWS Kinesis']
# 28                                       ['GCP PusSub']
# 29                                              ['GCP']
# 30                                            ['Azure']
# 31                                              ['AWS']
# 32    ['Excellent Unix/Linux experience and programm...
# 33                                   ['IPC mechanisms']
# 34                                           ['TCP/IP']
# 35                                            ['Kafka']
# 36                                     ['API gateways']
# 37                                      ['CAP Theorem']
# 38                                             ['RAFT']
# 39                                            ['Paxos']
# 40                                            ['CI/CD']
# 41                                           ['Github']
# 42                                        ['Makefiles']
# 43                                    ['Microservices']
# 44                                       ['GCPNode.js']
# 45       ['REST APIs servicesExperience writing tools']
# 46                                             ['Ruby']
# 47                                   ['PerlExperience']
# 48                                            ['Bazel']
# 49                                  ['HTTP /websocket']
# 50                                            ['Redis']
# 51                                 ['Web UIExperience']
# 52                                       ['JavaScript']
# 53                                             ['HTML']
# 54                                              ['CSS']
# 55                                          ['Angular']
# 56                                           ['Meteor']
# 57                                            ['Ember']
# 58                                         ['Knockout']
# 59                           ['UI Component libraries']
# 60                                              ['Vue']
# 61                                        ['Bootstrap']
# 62                                               ['ES']
# 63                                       ['TypeScript']
# 64                    ['Dependency injection patterns']
# 65                          ['Async Module Definition']
# 66                                   ['AMD, requireJS']
# 67                             ['Stylesheet languages']
# 68                                             ['SASS']
# 69                                            ['Redux']
# 70                             ['Reactive Programming']
# 71                                             ['RxJS']
# 72                    ['JavaStrong programming skills']
# 73                                  ['Guice knowledge']
# 74                               ['Protobuf knowledge']
# 75                                             ['APIs']
# 76                        ['Web UI:Deep understanding']
# 77                                             ['JSON']
# 78                                ['JavaScript Design']
# 79                           ['Architectural Patterns']
# 80                                      ['Proficiency']
# 81                                     ['Spring/Guice']
# 82                                    ['JPA/Hibernate']
# 83                                   ['JavaExperience']
# 84                             ['Containers knowledge']
# 85                          ['Multi-threaded concepts']
# 86                                            ['NoSQL']
# 87                                          ['MongoDB']
# 88                                        ['Cassandra']
# 89                         ['Java Application Servers']
# 90                                  ['Oracle WebLogic']
# 91                                            ['JBoss']
# 92                                           ['Tomcat']
# 93                                          ['Jasmine']
# 94                                            ['Karma']
# 95                                       ['Protractor']
# 96                                            ['Junit']
# 97                         ['Cross-browser techniques']
# 98                                 ['Chrome Dev Tools']
# 99                 ['Responsive design implementation']
# 100                    ['Browser performance auditing']
# 101                                  ['Scrum / Kanban']
# 102                                           ['Guice']
# 103                                            ['GRPC']
# 104   ['Excellent analytical and problem-solving ski...
# 105                           ['Proven-deep-expertise']
# 106                              ['Python programming']
# 107                                          ['Django']
# 108                                           ['Flask']
# 109                       ['Unix / Linux command line']
# 110                        ['Object-oriented concepts']
# 111                                   ['UI frameworks']
# 112                          ['Hadoop / Hive / Presto']
# 113                                ['ML/AI frameworks']
# 114                                      ['TensorFlow']
# 115                                           ['Mesos']
# 116                                      ['Kubernetes']
# 117                        ['Application benchmarking']
# 118            ['Building user interface applications']
# 119                                 ['UI Applications']
# 120                                             ['QML']
# 121                                          ['Qt/C++']
# 122                                           ['RasPi']
# 123                                      ['BeagleBone']
# 124                      ['IP-based network protocols']
# 125                  ['Myntra’s new product platforms']
# 126                                      ['Architects']
# 127                                ['DevOps engineers']
# 128                                          ['Myntra']
# 129                                         ['Java/GO']
# 130         ['Developing user-facing web applications']
# 131                                        ['Bachelor']
# 132                                ['Backend services']
# 133                                        ['React JS']
# 134                                   ['JS/TypeScript']
# 135                                ['Webpack bundling']
# 136                                       ['Dev tools']
# 137                                            ['HTML']
# 138                                             ['CSS']
# 139                                            ['SCSS']
# 140                                           ['Mysql']
# 141                                        ['Postgres']
# 142                            ['Data modeling skills']
# 143                            ['Detail Design phases']
# 144   ['Minimum  year Java design and development ex...
# 145            ['Spring and Hibernate based solutions']
# 146                       ['High-Quality Deliverables']
# 147                                            ['SOPs']
# 148                         ['Checks programming logs']
# 149                                          ['Inputs']
# 150                                         ['Handles']
# 151                                   ['Programs TLFs']
# 152                                             ['EAC']
# 153                                        ['BIOSETUP']
# 154                                             ['SAP']
# 155                           ['Shares accountability']
# 156                            ['ADaM reviewers guide']
# 157                                            ['SDRG']
# 158                                            ['ADRG']
# 159                                            ['RFPs']
# 160                ["Master's Degree Computer science"]
# 161              ["Bachelor's Degree Computer science"]
# 162                                 ['CDISC/ADaM/SDTM']
# 163                                        ['Base SAS']
# 164                                        ['SAS/STAT']
# 165                              ['SAS Macro Language']
# 166   ['Good organizational, interpersonal, leadersh...
# 167                                            ['Coda']
# 168                                             ['ETL']
# 169                                ['AWS technologies']
# 170                                        ['Redshift']
# 171                                             ['EMR']
# 172                                              ['EC']
# 173                                        ['DynamoDB']
# 174                                ['Kinesis Firehose']
# 175                                          ['Lambda']
# 176                                        ['ML teams']
# 177                                         ['Tableau']
# 178                               ['Bachelor’s degree']
# 179                            ['Hadoop/MapReduce/AWS']
# 180   ['Spark/Scala/PySpark/ Apache Kafka / Kinesis ...
# 181          ['Experience building flexible data APIs']
# 182                               ['Agile Development']
# 183                         ['Collaborative Filtering']
# 184                                ['Preferably, apps']
# 185                              ['XCode.. Experience']
# 186   ['Multi-threading and performance & memory opt...
# 187                                    ['RESTful APIs']
# 188                        ['Proficient understanding']
# 189                                             ['Git']
# 190                       ['Rubrik Software Engineers']
# 191                                 ['Master’s degree']
# 192                                           ['Scala']
# 193                 ['Google Cloud Platform/AWS/Azure']
# 194                         ['Unix/Linux environments']
# 195                            ['Windows environments']
# 196                              ['Kubernetes Service']
# 197                                ['RESTful services']
# 198                                ['Entity Framework']
# 199                                      ['Nhibernate']
# 200                             ['Strong TDD approach']
# 201                                           ['Nunit']
# 202                 ['OOP and SOLID design principles']
# 203   ['Highly efficient data persistent design tech...
# 204                           ['Proficient experience']
# 205                   ['Microsoft SQL Server/Postgres']
# 206                                 ['Agile practices']
# 207   ['Debugging/Troubleshooting functional and tec...
# 208             ['Performance/Optimization techniques']
# 209   ['Excellent analytical, quantitative, and prob...
# 210                            ['Strong interpersonal']
# 211                                         ['Xamarin']
# 212                                            ['LINQ']
# 213                                       ['Rest APIs']
# 214                                   ['Xamarin Forms']
# 215                      ['Xamarin Native development']
# 216                                  ['Xamarin Studio']
# 217                                    ['Xamarin Apps']
# 218                                             ['UWP']
# 219                                            ['XAML']
# 220                          ['Azure Active Directory']
# 221                                   ['Notifications']
# 222              ['HockeyApp/Visual Studio App Center']
# 223                          ['Continuous Integration']
# 224                                              ['CI']
# 225                                          ['DevOps']
# 226                              ['Automation Testing']
# 227                                ['Xamarin Profiler']
# 228                       ['Various code repositories']
# 229                                             ['TFS']
# 230                               ['MVVM Architecture']
# 231                                            ['VSTS']
# 232   ['Overall Cross Platform app development ecosy...
# 233                          ['Portable Class Library']
# 234                                             ['PCL']
# 235                                          ['SQLite']
# 236                                 ['Xamarin Binding']
# 237                   ['SAP HANA REST API Integration']
# 238                                       ['Core Java']
# 239                                   ['Swift / XCode']
# 240                                             ['CRM']
# 241                                             ['CMS']
# 242                         ['Highspot’s external API']
# 243              ['Highspot’s Salesforce integrations']
# 244                                              ['UX']
# 245         ['Highspot’s Infrastructure Platform crew']
# 246                                        ['Highspot']
# 247            ['Highspot’s feature engineering crews']
# 248                                         ['Clojure']
# 249                                            ['Node']
# 250                                      ['Typescript']
# 251                        ['Operational efficiencies']
# 252                   ['Collaborative build practices']
# 253                                             ['API']
# 254                                   ['UI components']
# 255                              ['Automated analysis']
# 256                                              ['UI']
# 257                                 ['Data annotation']
# 258                            ['Degree qualification']
# 259                           ['Ideally some exposure']
# 260                                ['Workplace Search']
# 261                                   ['Elasticsearch']
# 262                                          ['Kibana']
# 263                                          ['DevOPS']
# 264                                    ['Self-starter']
# 265                                             ['SLA']
# 266                         ['Strong TCP/IP knowledge']
# 267                                         ['Proxies']
# 268                                    ['NG Firewalls']
# 269                                       ['SSL/IPSec']
# 270                                             ['VPN']
# 271                                             ['SSO']
# 272                     ['DLP and Encryption gateways']
# 273                                      ['UNIX/Linux']
# 274                       ['Windows\xad based systems']
# 275                                             ['DNS']
# 276                                            ['DHCP']
# 277                                  ['Strong empathy']
# 278                            ['Interpersonal Skills']
# 279                                         ['Zendesk']
# 280                     ['Bachelors or Masters degree']
# 281                                 ['Excellent grasp']
# 282                                 ['MLOps processes']
# 283                                         ['SparkML']
# 284                                           ['NumPy']
# 285                                      ['Tensorflow']
# 286                                         ['PyTorch']
# 287                                           ['Keras']
# 288                                           ['Spark']
# 289                                         ['Jenkins']
# 290                                             ['GNN']
# 291                                              ['RL']
# 292                             ['Recommender Systems']
# 293                                  ['NLP techniques']
# 294                                        ['Analyzes']
# 295                                   ['QA test plans']
# 296                                            ['SDLC']
# 297                                           ['Agile']
# 298                     ['Micro-services architecture']
# 299                                       ['OpenShift']
# 300                                       ['K cluster']
# 301                                    ['Nginx/Ingres']
# 302                                     ['API Gateway']
# 303                                    ['Service Mesh']
# 304                        ['TortoiseGit / Sourcetree']
# 305                                       ['BitBucket']
# 306                                            ['JIRA']
# 307                                         ['Mockito']
# 308                             ['Application Servers']
# 309                                       ['WebSphere']
# 310                                ['Database Servers']
# 311                                      ['PostgreSQL']
# 312                                           ['MSSQL']
# 313                                           ['Linux']
# 314           ['Object Oriented Programming knowledge']
# 315                                            ['JAXB']
# 316                                  ['Apache Commons']
# 317                                      ['Apache POI']
# 318                                   ['Eclipse / STS']
# 319                                             ['XML']
# 320                                             ['XSD']
# 321                                      ['Apache Ant']
# 322                            ['Linux bash scripting']
# 323                                             ['DDL']
# 324                                             ['DML']
# 325                                            ['JDBC']
# 326                            ['Java Message Service']
# 327                                             ['JMS']
# 328                                        ['LiveView']
# 329                                           ['Rails']
# 330                                 ['API development']
# 331                                         ['Sinatra']
# 332                                          ['GitHub']
# 333                                  ['A strong grasp']
# 334                                             ['Exq']
# 335                                         ['Sidekiq']
# 336                                       ['Beanstalk']
# 337                                        ['RabbitMQ']
# 338                                          ['ExUnit']
# 339                                           ['RSpec']
# 340                                            ['Jest']
# 341                                          ['Elixir']
# 342                                    ['GraphQL APIs']
# 343                                        ['Absinthe']
# 344                                         ['GraphQL']
# 345                                  ['JavaScript SSR']
# 346                                     ['Willingness']
# 347                                           ['MySql']
# 348                                      ['Deployment']
# 349                             ['RESTful webservices']
# 350                                        ['InfluxDB']
# 351                                      ['Prometheus']
# 352                                         ['ReactJS']
# 353                                      ['UI changes']
# 354                                         ['UI Team']
# 355                                   ['HTML/CSS/SASS']
# 356                                              ['QA']
# 357                                       ['REST APIs']
# 358                                           ['Mocha']
# 359                                        ['UX teams']
# 360                                        ['CI tools']
# 361                      ['Dev-Ops Deployment process']
# 362                                         ['BDD/TDD']
# 363                                  ['BDD Experience']
# 364                                     ['RESTFUL API']
# 365                                       ['Scripting']
# 366                                         ['Grafana']
# 367                                        ['NewRelic']
# 368                                     ['Stackdriver']
# 369                                      ['Sumo Logic']
# 370                                      ['CloudWatch']
# 371                                           ['BS/MS']
# 372                                          ['Docker']
# 373                                        ['Perforce']
# 374                                    ['Android java']
# 375                                  ['Android Kotlin']
# 376                                      ['Buck/Bazel']
# 377                                          ['Golang']
# 378                                    ['REST/GraphQL']
# 379                             ['SQL/NoSQL Databases']
# 380                                       ['Micronaut']
# 381                                         ['Quarkus']
# 382                                 ['NoSQL Databases']
# 383                                   ['Event Brokers']
# 384                                            ['FaaS']
# 385   ['Terraform’s open source and commercial offer...
# 386                             ['HashiCorp customers']
# 387                                           ['Ph.D.']
# 388                                   ['ML techniques']
# 389                                            ['SVMs']
# 390           ['Entrepreneurial and positive attitude']
# 391                              ['Fortune  companies']
# 392                               ["Bachelor's degree"]
# 393                                      ['Networking']
# 394                                       ['HTTPS/SSL']
# 395                                   ['VLANs, TCP/IP']
# 396                                     ['NAT devices']
# 397                                    ['DHCP servers']
# 398                                       ['Firewalls']
# 399                              ['Genuine excitement']
# 400                                             ['IoT']
# 401                         ['Industry certifications']
# 402                                            ['CCNA']
# 403                                            ['CCDA']
# 404                                            ['CCNP']
# 405                                            ['MCSE']
# 406                                             ['CEH']
# 407                                 ['Microsoft Azure']
# 408                                           ['CISSP']
# 409                                             ['CSP']
# 410                                   ['Linux systems']
# 411                      ['Good theoretical grounding']
# 412             ['Excellent stakeholder communication']
# 413   ['Natural Language ProcessingContent & Context...
# 414                                        ['NetSuite']
# 415                   ['Netsuite ERP - Implementation']
# 416                                         ['Avalara']
# 417                                         ['Billing']
# 418                                             ['ERP']
# 419                         ['NetSuite ERP experience']
# 420                                  ['Salesforce.com']
# 421                                      ['Javascript']
# 422                           ['Unix scripts tool set']
# 423                                     ['SuiteScript']
# 424                                      ['SuiteFlows']
# 425                          ['Web Services/SuiteTalk']
# 426                        ['Exceptional communicator']
# 427            ['NetSuite Administrator Certification']
# 428                     ['Bachelors or masters degree']
# 429                   ['ERP implementation experience']
# 430         ['Excellent JavaScript development skills']
# 431                               ['Node.js ecosystem']
# 432                              ['Cloud environments']
# 433                       ['React web app development']
# 434                                             ['UIs']
# 435                ['Experience building API gateways']
# 436                                ['CI/CD technology']
# 437                      ['Real-time D/D applications']
# 438                                          ['Mentor']
# 439                                             ['TPM']
# 440                         ['VM/container management']
# 441                       ['Proven programming skills']
# 442                                         ['Node.js']
# 443                      ['Demonstrable understanding']
# 444                                      ['Observance']
# 445       ['Clean architectural and coding principles']
# 446                     ['Good problem-solving skills']
# 447           ['Excellent verbal communication skills']
# 448               ['Kotlin Multiplatform.. Experience']
# 449                       ['Mobile Automation Testing']
# 450                                        ['Fastlane']
# 451                                 ['CI/CD workflows']
# 452                                         ['SwiftUI']
# 453                                       ['Bitbucket']
# 454                                             ['TDD']
# 455                                     ['Android SDK']
# 456                ['Good verbal communication skills']
# 457                                 ['RxJava/RxKotlin']
# 458                                 ['Jetpack Compose']
# 459                                       ['Analytics']
# 460                                             ['SLI']
# 461                                             ['SLO']
# 462                                             ['TTR']
# 463                                            ['Toil']
# 464                                  ['Kibana/Grafana']
# 465                                        ['Logstash']
# 466                                ['Python/Kotlin/Go']
# 467         ['Real Time transaction protocols/methods']
# 468                                            ['HTTP']
# 469                                            ['MQTT']
# 470                                             ['UDP']
# 471                                     ['Operability']
# 472                                      ['Resilience']
# 473        ['Affirm’s Compute platform infrastructure']
# 474                          ["Affirm's future growth"]
# 475                                          ['Affirm']
# 476                                       ['MapReduce']
# 477                  ['Relational and NoSQL databases']
# 478                        ['Data Warehouse solutions']
# 479                                         ['Empathy']
# 480                                       ['Curiosity']
# 481                         ['Raft and Paxos variants']
# 482                     ['Build and architect systems']
# 483                                            ['TDDs']
# 484                               ['Bachelor’s Degree']
# 485                                        ['FP games']
# 486                                      ['FP success']
# 487                                           ['Obj-C']
# 488                     ['Exceptional problem solving']
# 489                                            ['B.S.']
# 490                   ['Shipped multiple applications']
# 491                  ['Experience building frameworks']
# 492                              ['Addressable Assets']
# 493                                   ['Asset Bundles']
# 494                                      ['WebSockets']
# 495                                  ['MZ development']
# 496             ['Linux and Mac OSX operating systems']
# 497                       ['Android release pipelines']
# 498                                      ['Subversion']
# 499                                         ['Mac OSX']
# 500                         ['Game Development Cycles']
# 501                                             ['Lua']
# 502                                             ['PHP']
# 503                                          ['Puppet']
# 504                                         ['Ansible']
# 505               ['Ship exceptional user experiences']
# 506                              ['Pragmatic approach']
# 507                                        ['Java/JEE']
# 508                                         ['Fluency']
# 509                                     ['Java Spring']
# 510                                          ['Vert.x']
# 511                                       ['SEO teams']
# 512                                          ['Solana']
# 513                                        ['Ethereum']
# 514                                 ['Blockchain tech']
# 515                         ['SQL and NoSQL databases']
# 516   ['Strong written and verbal communication skil...
# 517     ['Apache NiFi.. Golang service best practices']
# 518                           ['Deployment automation']
# 519                                         ['Webpack']
# 520                    ['Unix-based operating systems']
# 521                                ['QA methodologies']
# 522                                 ['CI/CD processes']
# 523                             ['API test automation']
# 524                                             ['VMs']
# 525                                ['Linux containers']
# 526                               ['Perfecto products']
# 527                     ['Java development experience']
# 528                              ['Strong proficiency']
# 529                     ['Java backend infrastructure']
# 530                                          ['NodeJS']
# 531                                    ['AWS platform']
# 532                                            ['B.Sc']
# 533                            ['Experience designing']
# 534                                         ['RocksDB']
# 535                   ['Frontend software development']
# 536                                    ['JS ecosystem']
# 537                                  ['SEO principles']
# 538                                 ['UX/user-empathy']
# 539                                       ['Terraform']
# 540                  ['Comprehensive systems hardware']
# 541   ['Common Linux distribution platform installat...
# 542                               ['TCP/IP networking']
# 543   ['NIC bonding and network services configurati...
# 544                                             ['NTP']
# 545                                            ['SMTP']
# 546                                          ['VMware']
# 547                                         ['Hyper-V']
# 548                                             ['KVM']
# 549                                            ['IaaS']
# 550                                            ['PaaS']
# 551                                            ['SaaS']
# 552          ['Experience managing networking devices']
# 553                                    ['DevOps tools']
# 554                                             ['NMS']
# 555                                      ['CSS levels']
# 556                                         ['Next.js']
# 557                                ['UI quality tools']
# 558                         ['Cloud Service Providers']
# 559                               ['AWS / Azure / GCP']
# 560                                          ['Kotlin']
# 561                         ['REST API based products']
# 562                                ['Strong reasoning']
# 563                                     ['Android dev']
# 564                                ['JS/AngularJS dev']
# 565                                            ['MVVM']
# 566                                 ['CameraX, Dagger']
# 567                                 ['TensorFlow lite']
# 568                                             ['KMM']
# 569                     ['Kotlin Multiplatform Mobile']
# 570                                           ['VueJS']
# 571                                          ['Bamboo']
# 572                           ['API design principles']
# 573                                 ['NoSQL databases']
# 574                    ['Site Reliability Engineering']
# 575                                             ['SRE']
# 576                                        ['Sonatype']
# 577                                         ['Haskell']
# 578                        ['Unix-based OS Experience']
# 579                              ['CI/CD technologies']
# 580                                  ['GitHub Actions']
# 581                                          ['Hadoop']
# 582                                            ['Hive']
# 583                                ['Jupyter Notebook']
# 584                                      ['Confluence']
# 585                              ['Dayforce personnel']
# 586                     ['Med - Large size/complexity']
# 587                          ['Web Services Protocols']
# 588                                             ['WCF']
# 589                              ['MVC web frameworks']
# 590    ['JavaScript-based web and mobile applications']
# 591                                   ['SaaS products']
# 592                                      ['PowerShell']
# 593             ['Azure and cloud-native architecture']
# 594                                 ['CI/CD pipelines']
# 595                                ['DevOps practices']
# 596            ['TSQL and relational database systems']
# 597                                           ['OAuth']
# 598                        ['OpenID Connect protocols']
# 599                     ['Multi-factor authentication']
# 600                                            ['Dojo']
# 601                                        ['Backbone']
# 602                                    ['SQL database']
# 603                                            ['TSQL']
# 604                                  ['Agile projects']
# 605                             ['Azure DevOps Server']
# 606                                ['CI build process']
# 607                       ['Azure/AWS cloud platforms']
# 608                        ['Android or Linux kernels']
# 609                                      ['Android OS']
# 610                           ['JavaScript frameworks']
# 611                   ['Kotlin / Kotlin multiplatform']
# 612                                  ['C++ programing']
# 613                     ['Swift programming expertise']
# 614                                     ['Apple’s HIG']
# 615                                ['Selenium/Gherkin']
# 616                                       ['Speckflow']
# 617                                         ['Gherkin']
# 618                                        ['Cucumber']
# 619                                        ['Specflow']
# 620                                           ['RDBMS']
# 621                             ['UI design tradeoffs']
# 622                                 ["Master's Degree"]
# 623              ["Bachelor's Degree Computer Science"]
# 624                                          ['Pillar']
# 625                                       ['AngularJS']
# 626                                         ['ASP.NET']
# 627                                         ['Web API']
# 628                            ['Dependency Injection']
# 629                                         ['Web Api']
# 630                            ['Entity Framework/ORM']
# 631                                 ['Multi-Threading']
# 632                   ['Object Oriented Design skills']
# 633    ['Strong written and oral communication skills']
# 634                  ['Basis Technologies DSP systems']
# 635                         ['Linux Operating Systems']
# 636                                       ['SaltStack']
# 637                                            ['Bash']
# 638                                     ['Diagnostics']
# 639                                          ['Athena']
# 640                                            ['Glue']
# 641                                       ['Big Query']
# 642                                        ['Dataproc']
# 643                                        ['Dataflow']
# 644         ['Google Cloud Platform data technologies']
# 645                                 ['Google BigQuery']
# 646                                 ['Google DataFlow']
# 647                                         ['PySpark']
# 648                                        ['SparkSQL']
# 649                                   ['Spark queries']
# 650                              ['Conventional RDBMS']
# 651                                        ['BigQuery']
# 652              ['Microsoft Azure SQL Data Warehouse']
# 653                                         ['Airflow']
# 654                                           ['Oozie']
# 655                                           ['Luigi']
# 656                                          ['Talend']
# 657                                         ['Pythian']
# 658                                            ['EGSE']
# 659                              ['Payload throughput']
# 660                        ['RF and digital equipment']
# 661        ['Digital channel processor specifications']
# 662            ['Direct Radiating Array (DRA) Antenna']
# 663        ['High capacity multiple spot beam systems']
# 664                                ['Flexible payload']
# 665                            ['Multi-Port Amplifier']
# 666                           ['RF and system payload']
# 667                                  ['French fluency']
# 668                  ['Excellent interpersonal skills']
# 669                                             ['IaC']
# 670                                      ['PCB design']
# 671                                            ['FPGA']
# 672                                              ['RF']
# 673          ['Relevant DevOps engineering experience']
# 674                                          ['Groovy']
# 675                                        ['Montréal']
# 676                     ['Linux system administration']
# 677                                         ['Git/SVN']
# 678                                          ['GitLab']
# 679                                     ['Azure Cloud']
# 680              ['Docker and container orchestrators']
# 681                                   ['SQL Databases']
# 682                                             ['TLS']
# 683                                       ['GUI tools']
# 684                                         ['VSphere']
# 685                                      ['VirtualBox']
# 686                                ['DevOps Engineers']
# 687   ['DevOps automation/infrastructure/product del...
# 688                                       ['ALM tools']
# 689                                ['Active Directory']
# 690                              ['Azure technologies']
# 691                                         ['Compute']
# 692                     ['SQL/Cosmos/Mongo/PostGreSQL']
# 693                                   ['User journeys']
# 694                                   ['Oracle Siebel']
# 695                        ['Oracle Policy Automation']
# 696                                      ['Middleware']
# 697                             ['A bachelor’s degree']
# 698                           ['Siebel SOAP Structure']
# 699                                           ['WSDLs']
# 700                                            ['XSDs']
# 701                                            ['XSLT']
# 702                                            ['XMLs']
# 703                                ['Siebel Workflows']
# 704                        ['Error/Exception Handling']
# 705            ['Siebel Integration Object structures']
# 706                           ['EAI Business Services']
# 707                            ['Siebel Configuration']
# 708                  ['SQL / Store procedure creation']
# 709                  ['Siebel enterprise architecture']
# 710                                  ['Siebel Open UI']
# 711                                     ['Java Script']
# 712               ['Siebel Public Sector applications']
# 713                             ['Technical expertise']
# 714   ['Experience designing and developing APIs, we...
# 715                                           ['Scrum']
# 716                                      ['Agile team']
# 717                               ['Automated testing']
# 718                   ['Agile development environment']
# 719      ['Strong written/verbal communication skills']
# 720                                 ['Bachelor degree']
# 721   ['Highly motivated, enthusiastic, and a positi...
# 722                                         ['VxWorks']
# 723                                             ['RTX']
# 724                                           ['RTEMS']
# 725                       ['Communications interfaces']
# 726                                             ['SPI']
# 727                                        ['EtherCAT']
# 728                                            ['ATDD']
# 729                                             ['BDD']
# 730         ['Continuous integration/build automation']
# 731                        ['Windows Active Directory']
# 732                                ['Azure AD Connect']
# 733    ["Microsoft's Active Directory Domain Services"]
# 734                                           ['AD CS']
# 735   ["Microsoft's Active Directory Federation Serv...
# 736                                           ['AD FS']
# 737                                          ['AD LDS']
# 738   ["Microsoft's Active Directory Rights Manageme...
# 739                                             ['RMS']
# 740                                             ['MFA']
# 741                                            ['SSPR']
# 742                                             ['ATA']
# 743                                         ['FIM/MIM']
# 744                          ['L/L production support']
# 745                                  ['Qualifications']
# 746                      ['Microsoft Active Directory']
# 747   ['Azure AD Zero Trust components implementation']
# 748                              ['Conditional Access']
# 749                                            ['SAML']
# 750                                  ['Azure AD proxy']
# 751   ['Microsoft’s advanced security and networking...
# 752                                       ['Key Vault']
# 753                                        ['Sentinel']
# 754   ['Organization/Folder/Project/Resource structu...
# 755                                          ['Intune']
# 756                ['Conditional Access \\ MDM \\ MAM']
# 757          ['Tenant \\ Security & Compliance Center']
# 758                                       ['Archiving']
# 759   ['M Security & Compliance  Strong PowerShell s...
# 760    ['Microsoft  security and strategy discussions']
# 761                        ['IaaS/PaaS/SaaS platforms']
# 762                              ['GCP certifications']
# 763                      ['Scope Key Candidate Skills']
# 764                                             ['HSM']
# 765                                  ['Integrated DLP']
# 766                                   ['CI/CD systems']
# 767                                   ['Observability']
# 768                                 ['Telemetry tools']
# 769                                           ['Salus']
# 770                                          ['AppSec']
# 771                          ['A/B testing frameworks']
# 772                           ['Blockchain technology']
# 773                      ['Wrapbook customer problems']
# 774                                       ['Mentoring']
# 775                                     ['SQL queries']
# 776                              ['Rails applications']
# 777                                     ['SQL indices']
# 778                       ['Agile or Lean environment']
# 779                                   ['Proven mentor']
# 780                           ['Javascript/Typescript']
# 781           ['Ada’s builder experience organization']
# 782                               ['Ada’s application']
# 783                         ['Required Qualifications']
# 784                                ['Hadoop ecosystem']
# 785                                      ['Spark jobs']
# 786                                          ['HiveQL']
# 787                          ['Hadoop Clusters Proven']
# 788                                      ['Azure ADLS']
# 789                                ['Linux enviroment']
# 790                        ['Automation opportunities']
# 791                                       ['Bug fixes']
# 792                     ['Required Skills Linux Spark']
# 793                     ['SQL Hadoop Ecosystem - Hive']
# 794                                             ['Tez']
# 795   ['Optional Skills Azure Services Python Autosys']
# 796                                     ['Plastic SCM']
# 797                                            ['Helm']
# 798                                    ['AWS products']
# 799   ['Excellent written and oral communication ski...
# 800                              ['QA test procedures']
# 801                  ['Troubleshooting quality issues']
# 802                       ['Quality Assurance reports']
# 803                                      ['Automation']
# 804                              ['Testing Automation']
# 805              ['Software Development methodologies']
# 806                             ['Kubernetes clusters']
# 807                                            ['MTTR']
# 808                                     ['SLO targets']
# 809                                     ['DevOps role']
# 810                                 ['VictoriaMetrics']
# 811                                         ['Datadog']
# 812                                          ['Zabbix']
# 813                                            ['SLIs']
# 814                                            ['SLOs']
# 815                      ['SAS programming activities']
# 816                      ['SAS Programming activities']
# 817                                      ['TFL shells']
# 818                     ['Company generic macro usage']
# 819                      ['CDISC compliant tabulation']
# 820                ['CDISC therapeutic area standards']
# 821                                      ['TFL output']
# 822                       ['Archive deliverable files']
# 823                               ['Lead Statistician']
# 824        ['Lead Biostatistician and Project Manager']
# 825                       ['SAS Programming expertise']
# 826           ['SAS Programming Subject Matter Expert']
# 827     ['Support SAS Programming process improvement']
# 828          ['SAS Programming Client Account Manager']
# 829                                 ['SAS Programming']
# 830                ['Company SAS Programming services']
# 831                                 ['SAS Programmers']
# 832                          ['Accurately record time']
# 833                      ['SAS programming experience']
# 834                                 ['Master’s Degree']
# 835                                      ['CDISC SDTM']
# 836                  ['ADaM Implementation Guidelines']
# 837                 ['Excellent organizational skills']
# 838                                        ['Sponsors']
# 839                       ['Strong Analytical mindset']
# 840                                           ['CDASH']
# 841                                 ['CDISC standards']
# 842                      ['Annotate case report forms']
# 843                                            ['CRFs']
# 844                                            ['SDTM']
# 845                    ['SDTM specifications document']
# 846                  ['CDISC Implementation Guideline']
# 847                                   ['XML documents']
# 848   ['Biostatistical programming and Biostatistica...
# 849                                        ['SAS code']
# 850                                        ['Listings']
# 851                                 ['Figures outputs']
# 852                                    ['SAS programs']
# 853                                 ['QC SAS programs']
# 854                                         ['Dataset']
# 855                      ['Train and mentor new hires']
# ...
# 6262     ['Proficiency and enterprise work experience']
# 6263                             ['Angular (Angular +']
# 6264                    ['Data Technology Consultants']
# 6265  ['Any object-oriented/object function scriptin...
# 6266                                 ['Azure: Storage']
# 6267                      ['ReduxAngularJSRxJSVirtual']
# 6268                                   ['Real DOMsMVC']
# 6269         ['Design & Develop web backend solutions']
# 6270                   ['Strong database fundamentals']
# 6271                                 ['ReduxKnowledge']
# 6272           ['MVP patternsCore JavaScriptCSS, HTML']
# 6273                                       ['Adaptive']
# 6274                                       ['JS, Java']
# 6275                            ['Core JavaCreational']
# 6276                              ['Web DesignRESTful']
# 6277                                          ['APICI']
# 6278                           ['Automation Framework']
# 6279                          ['Defects documentation']
# 6280                        ['REST & SOAP API testing']
# 6281                                         ['SOAPUI']
# 6282                               ['Groovy Scripting']
# 6283  ['Excellent organizational, troubleshooting an...
# 6284               ['Scope and estimate project tasks']
# 6285                                   ['Flask/Django']
# 6286                           ['Strong SQL knowledge']
# 6287                                          ['AWS\\']
# 6288                                ['An acquaintance']
# 6289                         ['Strong Linux knowledge']
# 6290                                           ['GPFS']
# 6291                       ['Configuration management']
# 6292                                        ['Ganglia']
# 6293                          ['NFS/SAMBA/GPFS/Lustre']
# 6294                                   ['Provisioning']
# 6295                                        ['Foreman']
# 6296                               ['RedHat Satellite']
# 6297                         ['Strong Troubleshooting']
# 6298                                        ['FinTech']
# 6299                                     ['Enablement']
# 6300                                   ['Spring Batch']
# 6301                                        ['SQLNice']
# 6302                                         ['JMS/MQ']
# 6303                               ['Splunk/Dynatrace']
# 6304                                  ['CSSExperience']
# 6305          ['Mainframe/Backend Systems - Knowledge']
# 6306                                      ['SmartBear']
# 6307                               ['Reporting - Jira']
# 6308                           ['Mainframe Automation']
# 6309                                       ['Serenity']
# 6310  ['Excellent communication and documentation sk...
# 6311                 ['Smart Contract security audits']
# 6312                          ['NFT related protocols']
# 6313                                           ['ERC-']
# 6314                                            ['ERC']
# 6315                             ['Solidity contracts']
# 6316                                     ['L networks']
# 6317                                        ['Polygon']
# 6318                                        ['Slither']
# 6319                                        ['Echidna']
# 6320                                        ['Mythril']
# 6321                                    ['HW bring-up']
# 6322                                 ['ARM Cortex M/A']
# 6323                                          ['LINUX']
# 6324                                            ['IIC']
# 6325                               ['FPGA development']
# 6326                          ['ASIC development flow']
# 6327                                            ['RTL']
# 6328                                ['SIMD processors']
# 6329                                           ['GPUs']
# 6330                                          ['FPGAs']
# 6331                                          ['Amgen']
# 6332                              ['DevOps frameworks']
# 6333                          ['Informatics solutions']
# 6334                              ['High School / GED']
# 6335                          ['High learning agility']
# 6336       ['Office  Power Platform environment tools']
# 6337                                  ['SQL reporting']
# 6338                           ['Hands-on hour series']
# 6339                             ['PPAP documentation']
# 6340                                           ['APQP']
# 6341                                           ['FMEA']
# 6342                                  ['NCE-Prototype']
# 6343                                  ['D methodology']
# 6344                                     ['Lead PFMEA']
# 6345                            ['Zero Defect program']
# 6346    ['Electrical or Mechanical Engineering Degree']
# 6347                                          ['PFMEA']
# 6348     ['Strong analytical and communication skills']
# 6349                                             ['TD']
# 6350                     ['Monitor system life cycles']
# 6351                                        ['RFI/RFP']
# 6352                                           ['SLAs']
# 6353                           ['Undergraduate Degree']
# 6354                                      ['Adeptness']
# 6355                ['Strong subject matter expertise']
# 6356                                      ['Readiness']
# 6357                                    ['TD services']
# 6358                             ['Skillsets Required']
# 6359                     ['Now related configurations']
# 6360                             ['SQL/NoSQL database']
# 6361                                          ['G RAN']
# 6362                                            ['OAM']
# 6363                                  ['OEM solutions']
# 6364                                     ['G networks']
# 6365                                           ['SCTP']
# 6366                      ['Precision Timing Protocol']
# 6367                                            ['PTP']
# 6368                                      ['Fronthaul']
# 6369                                        ['Midhaul']
# 6370                                       ['Backhaul']
# 6371                  ['G/G SW development experience']
# 6372               ['Carrier grade Transport solution']
# 6373         ['Organized, goal-oriented, self-starter']
# 6374      ['Demonstrable C/C++ programming experience']
# 6375                                        ['AWS IoT']
# 6376                                         ['RDS, S']
# 6377                                        ['EKS/ECS']
# 6378                              ['Python frameworks']
# 6379                  ['Python Data Science Libraries']
# 6380  ['Data Analysis/Data Cleaning/Feature Engineer...
# 6381            ['Sagemaker/Step Function/ECS/Lambdas']
# 6382                              ['RTOS environments']
# 6383                        ['Board Software Packages']
# 6384                                           ['BSPs']
# 6385                     ['SPI and Ethernet protocols']
# 6386                                         ['OpenVG']
# 6387                 ['Champion core DevOps behaviors']
# 6388                       ['Azure Certifications AZ-']
# 6389                                            ['AZ-']
# 6390                            ['NodeJs applications']
# 6391                                 ['Octopus Deploy']
# 6392                              ['GitHub Enterprise']
# 6393                             ['Swift/Objective-C.']
# 6394                    ['OOP, SOLID, Design Patterns']
# 6395              ['Experience consuming web services']
# 6396                             ['Azure environments']
# 6397                                      ['Geography']
# 6398                                         ['ArcMap']
# 6399                  ["Sonder's reporting dashboards"]
# 6400                              ['Sonder’s business']
# 6401                         ['Sonder’s business KPIs']
# 6402                    ['Expert Python coding skills']
# 6403            ['Expert SQL and data modeling skills']
# 6404                                       ['ETL jobs']
# 6405  ['Commercial and Leadership/Mentorship exposure']
# 6406                          ['Fullstack development']
# 6407                     ['Strong Frontend background']
# 6408                                    ['React/Redux']
# 6409                      ['Strong Backend background']
# 6410   ['Research new cloud and software technologies']
# 6411  ['Complete self-paced and online professional ...
# 6412                     ['Current AWS certifications']
# 6413                          ['RideFlag applications']
# 6414                           ['VIPER design pattern']
# 6415                                            ['DDP']
# 6416                               ['Docker/Container']
# 6417                                  ['MOBIA clients']
# 6418                                          ['MOBIA']
# 6419                              ['Red Hat OpenShift']
# 6420                              ['Red Hat OpenStack']
# 6421                                  ['Google Anthos']
# 6422                                 ['PaaS solutions']
# 6423                                ['HashiCorp stack']
# 6424            ['Bilingual (French/English) language']
# 6425                                  ['USB interface']
# 6426                                            ['IVI']
# 6427                         ['Self-starter/motivator']
# 6428                         ['Outstanding work ethic']
# 6429                            ['Computer Networking']
# 6430                            ['Public Cloud Stacks']
# 6431                                           ['MSAZ']
# 6432                        ['Public Cloud Networking']
# 6433                                       ['Wireline']
# 6434                               ['CDN technologies']
# 6435                                      ['BGP, ISIS']
# 6436                                ['Segment Routing']
# 6437                                           ['EVPN']
# 6438                     ['Bilingual - French/English']
# 6439                                  ['CI/CD tooling']
# 6440                                  ['ARM Templates']
# 6441                                  ['GCP Templates']
# 6442                   ['Workplace culture enthusiast']
# 6443         ['Infrastructure and Cybersecurity teams']
# 6444                                  ['O environment']
# 6445                                       ['OneDrive']
# 6446                    ['OS deployment configuration']
# 6447                                      ['WIM files']
# 6448                                ['Driver Packages']
# 6449                      ['Customized Task Sequences']
# 6450                                      ['UEFI/BIOS']
# 6451                         ['Registry Configuration']
# 6452                ['Azure Virtual Desktop..  Design']
# 6453                     ['Video Conferencing systems']
# 6454                          ['Bayshore EA standards']
# 6455                               ['XDR technologies']
# 6456                                            ['ATP']
# 6457            ['Windows  OS and associated services']
# 6458                                            ['AAD']
# 6459                                      ['Azure MFA']
# 6460                                       ['SSO Apps']
# 6461                                    ['AAD connect']
# 6462                          ['M tenant/applications']
# 6463                                        ['ProPlus']
# 6464                            ['Enterprise Mobility']
# 6465                                    ['Smartphones']
# 6466                              ['O solution design']
# 6467                               ['DMZ architecture']
# 6468                ['Security and Privacy Frameworks']
# 6469                                         ['PIPEDA']
# 6470                                          ['PHIPA']
# 6471                                            ['SOC']
# 6472                                ['Microsoft Graph']
# 6473                                           ['IaaC']
# 6474                              ['Ansible/Terraform']
# 6475                                    ['Microsoft O']
# 6476         ['Modern Desktop Administrator Associate']
# 6477                          ['Identity Fundamentals']
# 6478                                       ['Logitech']
# 6479                                 ['Poly..  Design']
# 6480                          ['Azure Virtual Desktop']
# 6481                  ['Java/JavaScript/Groovy/Python']
# 6482  ['IntelliJ/Eclipse/Visual Code/WebStorm..  Exp...
# 6483                                        ['MacOS X']
# 6484                          ['Cypher query language']
# 6485                              ['Java RESTful APIs']
# 6486                          ['Strong UI development']
# 6487                                   ['JS Framework']
# 6488                              ['RESTful Java APIs']
# 6489                     ['Microservices Architecture']
# 6490                       ['Strong SQL coding skills']
# 6491                  ['Strong problem-solving skills']
# 6492                          ['C#, ASP.NET framework']
# 6493                                    ['DotNet Core']
# 6494                                 ['MVC/Razor page']
# 6495                                     ['Net WebAPI']
# 6496                                  ['HTML/SASS/CSS']
# 6497                    ['MS SQL database development']
# 6498                ['Strong design and coding skills']
# 6499                                       ['QA teams']
# 6500                                        ['QA time']
# 6501                                    ['J avaScript']
# 6502                            ['J SON et PowerShell']
# 6503            ['PowerBI or data visualization tools']
# 6504         ['Full lifecycle application development']
# 6505                                  ['Angular, Java']
# 6506                                        ['HL FHIR']
# 6507                    ['SPA application development']
# 6508                             ['Angular, Bootstrap']
# 6509                                ['HTML/CSS/JS, ES']
# 6510                                 ['OpenID Connect']
# 6511                               ['RedHat OpenShift']
# 6512                                             ['HL']
# 6513                  ["A completed Bachelor's degree"]
# 6514                              ['Actuarial Science']
# 6515                                   ['ICAAP models']
# 6516                                           ['IFRS']
# 6517                                       ['Basel II']
# 6518                                       ['SAS Base']
# 6519                                         ['SAS EG']
# 6520                              ['LCHH format/model']
# 6521                                   ['HTML/CSS/PhP']
# 6522                                 ['QA specialists']
# 6523                                ['Accomplishments']
# 6524   ['Microsoft Azure cloud development experience']
# 6525                                          ['Perks']
# 6526                                   ['MVP releases']
# 6527                                  ['MM interfaces']
# 6528                                ['NoSQL/KV Stores']
# 6529                     ['Messaging Queuing Services']
# 6530                                     ['GitHub use']
# 6531  ['Results-oriented, data-driven, experimental ...
# 6532                           ['Boundless positivity']
# 6533  ['Strong troubleshooting and problem-solving s...
# 6534                                        ['Statflo']
# 6535                  ['Roku applications development']
# 6536                              ['Roku applications']
# 6537                        ['Brightscript Scenegraph']
# 6538                              ['Swift/Objective-C']
# 6539                   ['Server-side scripting skills']
# 6540                                ['Bitbucket / Git']
# 6541                  ['Agile, Continuous Integration']
# 6542                                           ['CMIS']
# 6543                          ['C / embedded software']
# 6544                           ['Leadership qualities']
# 6545                                       ['Actalent']
# 6546  ['Self-motivated, enthusiastic and strong drive']
