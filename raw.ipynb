# %%
import pandas as pd

# %%
df = pd.read_csv("Raw_Skills_Dataset.csv")

# %%
df.shape
# Out:
# (34116, 1)

# %%
df.head()
# Out:
#           RAW DATA
# 0         What ifs
# 1        seniority
# 2      familiarity
# 3  functionalities
# 4          Lambdas

# %%
df.dropna(inplace = True)

# %%
df.shape
# Out:
# (34116, 1)

# %%
df1 = df.drop_duplicates()

# %%
df1.shape
# Out:
# (15677, 1)

# %%
pd.set_option('display.max_rows', None)

# %%
#df

# %%
df1['RAW DATA'] = df['RAW DATA'].str.replace('\d+', '')
# Out:
# C:\Users\NMR\AppData\Local\Temp/ipykernel_11352/3140575984.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df1['RAW DATA'] = df['RAW DATA'].str.replace('\d+', '')
# C:\Users\NMR\AppData\Local\Temp/ipykernel_11352/3140575984.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['RAW DATA'] = df['RAW DATA'].str.replace('\d+', '')

# %%
df1.to_csv("df1.csv")

# %%
df1.shape
# Out:
# (15677, 1)

# %%
from csv import DictReader
with open("df1.csv",'r') as f:
    csv_dict_reader = DictReader(f)
    for row in csv_dict_reader:
        print(row['RAW DATA'])
# Out:
# What ifs
# seniority
# familiarity
# functionalities
# Lambdas
# Java Streams
# Object Oriented analysis
# Relational Databases
# SQL
# ORM
# JPA
# Hibernate
# MyBatis
# code versioning tools
# Git.. Familiarity
# Maven
# Gradle.. Familiarity
# continuous integration
# continuous delivery development processes
# jenkins
# bamboo
# Familiarity
# frameworks
# transformations
# analytical reporting
# conceptual data models
# standard naming conventions
# coding practices
# consistency
# optimized solutions
# methodologies
# high throughput data access services
# analyze/profile data
# conceptual, logical & physical data model designs
# reporting and analytics solutions
# physical databases
# variances
# discrepancies
# all phases
# integrations
# Demonstrable experience
# logical and physical data models
# interpersonal skills
# modern enterprise data architectures
# data toolsets
# e.g.: data warehouse
# data marts
# modeling tools
# profiling tools
# Bachelor or Master degree
# ...

# %%
#for row in df1.iterrows():
#    print(row)

# %%
elements = ["xxxxxx", "yyy", "z"]
for element in elements:
    print(len(element))
# Out:
# 6
# 3
# 1

# %%
#import seaborn as sns
#sns.heatmap(df1.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
y = df1['RAW DATA'].str.findall(r'(^[A-Z].*)')

# %%
y.replace(to_replace ="[]",
                 value ="")
# Out:
# 0                                             [What ifs]
# 1                                                     []
# 2                                                     []
# 3                                                     []
# 4                                              [Lambdas]
#                               ...
# 34106                             [Leadership qualities]
# 34108                                         [Actalent]
# 34109                                                 []
# 34110    [Self-motivated, enthusiastic and strong drive]
# 34111                                                 []
# Name: RAW DATA, Length: 15677, dtype: object

# %%
y.to_csv("try.csv", index = False)

# %%
dfy2 = pd.read_csv("try.csv")

# %%
dfy2.head(20)
# Out:
#                         RAW DATA
# 0                   ['What ifs']
# 1                             []
# 2                             []
# 3                             []
# 4                    ['Lambdas']
# 5               ['Java Streams']
# 6   ['Object Oriented analysis']
# 7       ['Relational Databases']
# 8                        ['SQL']
# 9                        ['ORM']
# 10                       ['JPA']
# 11                 ['Hibernate']
# 12                   ['MyBatis']
# 13                            []
# 14         ['Git.. Familiarity']
# 15                     ['Maven']
# 16      ['Gradle.. Familiarity']
# 17                            []
# 18                            []
# 19                            []

# %%
l = []

# %%
from csv import DictReader
with open("try.csv",'r',encoding="utf-8") as f:
    csv_dict_reader = DictReader(f)
    for row in csv_dict_reader:
        l.append(row['RAW DATA'])
        #print(row['RAW DATA'])

# %%
#l

# %%
a = []
for i in l:
    if i!='[]'':
        a.append(i)

# %%
len(a)
# Out:
# 9964

# %%
az = []
import json
for i in a:
   az.append(len(i))
min(az)
# Out:
# 5

# %%
print
# Out:
# [12,
#  11,
#  16,
#  28,
#  24,
#  7,
#  7,
#  7,
#  13,
#  11,
#  21,
#  9,
#  24,
#  15,
#  27,
#  29,
#  15,
#  21,
#  10,
#  32,
#  27,
#  9,
#  10,
#  16,
#  14,
#  34,
#  16,
#  10,
#  22,
#  15,
#  14,
#  7,
#  9,
#  7,
#  62,
#  18,
#  10,
#  9,
#  16,
#  15,
#  8,
#  9,
#  9,
#  10,
#  13,
#  17,
#  14,
#  46,
#  8,
#  18,
#  9,
#  19,
#  9,
#  20,
#  14,
#  8,
#  7,
#  11,
#  10,
#  9,
#  12,
#  26,
#  7,
#  13,
#  6,
#  14,
#  33,
#  27,
#  18,
#  24,
#  8,
#  9,
#  24,
#  8,
#  33,
#  19,
#  22,
#  8,
#  29,
#  8,
#  21,
#  26,
#  15,
#  16,
#  17,
#  18,
#  24,
#  27,
#  9,
#  11,
#  13,
#  28,
#  19,
#  9,
#  10,
#  11,
#  9,
#  14,
#  9,
#  28,
#  20,
#  36,
#  32,
#  18,
#  9,
#  8,
#  51,
#  25,
#  22,
#  10,
#  9,
#  29,
#  28,
#  17,
#  26,
#  20,
#  14,
#  5,
#  9,
#  14,
#  28,
#  40,
#  19,
#  7,
#  10,
#  9,
#  14,
#  30,
#  36,
#  14,
#  20,
#  10,
#  11,
#  43,
#  12,
#  20,
#  12,
#  17,
#  20,
#  13,
#  8,
#  7,
#  8,
#  9,
#  12,
#  24,
#  24,
#  56,
# ...

# %%
a
# Out:
# ["['What ifs']",
#  "['Lambdas']",
#  "['Java Streams']",
#  "['Object Oriented analysis']",
#  "['Relational Databases']",
#  "['SQL']",
#  "['ORM']",
#  "['JPA']",
#  "['Hibernate']",
#  "['MyBatis']",
#  "['Git.. Familiarity']",
#  "['Maven']",
#  "['Gradle.. Familiarity']",
#  "['Familiarity']",
#  "['Demonstrable experience']",
#  "['Bachelor or Master degree']",
#  "['STEM majors']",
#  "['Strong algorithms']",
#  "['Python']",
#  "['Scala programming experience']",
#  "['Exceptional proficiency']",
#  "['MySQL']",
#  "['Oracle']",
#  "['NoSQL Stores']",
#  "['Clickhouse']",
#  "['Distributed Processing Engines']",
#  "['Apache Flink']",
#  "['Celery']",
#  "['Distributed Queues']",
#  "['AWS Kinesis']",
#  "['GCP PusSub']",
#  "['GCP']",
#  "['Azure']",
#  "['AWS']",
#  "['Excellent Unix/Linux experience and programming experience']",
#  "['IPC mechanisms']",
#  "['TCP/IP']",
#  "['Kafka']",
#  "['API gateways']",
#  "['CAP Theorem']",
#  "['RAFT']",
#  "['Paxos']",
# ...

# %%
adf = pd.DataFrame(a, columns = ['RAW DATA'])

# %%
adf.head()
# Out:
#                        RAW DATA
# 0                  ['What ifs']
# 1                   ['Lambdas']
# 2              ['Java Streams']
# 3  ['Object Oriented analysis']
# 4      ['Relational Databases']

# %%
#dfy['RAW DATA'].dropna()

# %%
dfy.dropna(inplace = True)
# Out:
# c:\users\nmr\appdata\local\programs\python\python39\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
len(dfy)
# Out:
# 15678

# %%
dfy.head()
# Out:
#        RAW DATA
# 0  ['What ifs']
# 1            []
# 2            []
# 3            []
# 4   ['Lambdas']
